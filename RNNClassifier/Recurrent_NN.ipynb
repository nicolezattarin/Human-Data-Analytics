# %% [markdown]
# # Recurrent Neural Network

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import time
import os
import zipfile
from scipy.signal import medfilt
from tqdm import tqdm
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, roc_curve, auc, accuracy_score, precision_recall_curve
import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (10, 6)
mpl.rcParams['axes.grid'] = True
mpl.rcParams['legend.fontsize'] = 'large'

# %% [markdown]
#  ## 1 - Data loading and preprocessing
#  The dataset includes single-lead short ECG recording (between 30 s and 60 s in length), whether the recording shows normal sinus rhythm, atrial fibrillation (Afib), an alternative rhythm, or is too noisy to be classified.
#
#  To make the problem a little bit easier, in this class we will just consider normal sinus rhythm and Afib traces, trying to train a classifier that is able to discriminate between these two cases.
#
#  More information about the dataset can be found here: [https://physionet.org/challenge/2017/](https://physionet.org/challenge/2017/)

# %% [markdown]
#  ### 1.2 - Create data folder
#  First, if not done yet, let's decompress the zip data file.

# %%
# Define the data folder location
data_dir = 'data'

# Extract data from zip file
if not os.path.exists(data_dir):
    with zipfile.ZipFile('data.zip', 'r') as f:
        f.extractall('.')

# %% [markdown]
# ### 1.3 - Import labels
#
# Each signal is stored in a separate file in the "./data" folder, while the labels are listed in the "./data/REFERENCE-v3.csv" file.
#
# The label file includes two columns, the first represents the filename where the data is stored, and the second represents the actual label, manually determined by human experts. The labels are:
#  - **N** -> Normal sinus rhythm
#  - **A** -> Atrial Fibrillation
#  - **O** -> Other abnormal rhythms
#  - **~** -> Noisy traces
#
#
# The following code performs these operations:
# - Load the reference file as a Pandas dataframe object ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)). Use the ``read_csv`` function of the pandas library (here imported as `pd`) ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html#pandas.read_csv)) using as parameters: ```index_col=0``` to use column 0 as row labels, ```header=None``` and ```names=['label']``` to use 'label' as the name of the column
#
# - Select only the files with labels **N** or **A** using masking. To create the mask: use ```(reference_df['label'] == 'xxx')``` to set one condition for the selection and combine the two conditions using the **or** operator ```condition1 | condition2```. Apply the mask using:
# ```python
# reference_df[mask]
# ```
#
#
# - Replace **N** with 0 (negative class) and **A** with 1 (positive class). Use the ``apply`` function of pandas ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html)) that is used to apply a function to a DataFrame. Our function is ```lambda l: 0 if l == 'N' else 1```: see [here](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) the documentation for the "lambda" keyword. Putting all together, the final expression to use is:
# ```python
# reference_df['label'] = reference_df['label'].apply(lambda l: 0 if l == 'N' else 1)
# ```

# %%
# Create a dataframe containing all the files and the labels from the reference file
reference_df = pd.read_csv(os.path.join(data_dir, 'REFERENCE-v3.csv'), header=None, names=['file', 'label'])

# Just consider the 'N' and the 'A' class
mask = (reference_df['label'] == 'N') | (reference_df['label'] == 'A')
reference_df = reference_df[mask]

# Replace 'N' with 0 and 'A' with 1
reference_df['label'] = reference_df['label'].replace({'N': 0, 'A': 1})

# Print the result
print(reference_df)
# Out:
#         file  label
# 0     A00001      0
# 1     A00002      0
# 2     A00003      0
# 3     A00004      1
# 4     A00005      1
# ...      ...    ...
# 8522  A08523      1
# 8523  A08524      0
# 8525  A08526      0
# 8526  A08527      0
# 8527  A08528      0
#
# [5834 rows x 2 columns]

# %% [markdown]
# ### 1.4 - Create a validation set
# As you can see from the previous output, we have now proper labeling for each file to be used with our loss function. Of course, we still need to load the actual data.
#
# However, before loading the data, let's keep a subset of data out for validation (20% of the data).
#
# To this end, use the `train_test_split` function from the scikit-learn library as done in Lab 3 ([documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)). Specifically, for the function parameters:
#
# - use the proper ```test_size``` parameter to retain 20% of data for validation
# - set ```stratify=reference_df['label']``` to keep the percentage of elements for each class equally distributed among the train and the validation set
# - ```random_state=123``` for reproducible outputs
#
# **Hint**: Take also a look at different splitting strategies provided by scikit-learn [here](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.model_selection). These are extremely useful for many machine learning tasks, especially for cross-validation.
#
# **NOTE**: If your hardware is not powerful enough, or if you want to perform some tests without loading the entire dataset, just set *smoke_test=True*. This will reduce the train and validation set to only *smoke_test_size* elements. Of course, the results won't be reliable, but this may be useful to test if everything is working as intended before the full training.

# %%
# Enable smoke test
smoke_test = False
smoke_test_size = 50

# Keep 20% of the data out for validation
train_reference_df, val_reference_df = train_test_split(reference_df, test_size=0.2, random_state=42, stratify=reference_df['label'])

if smoke_test:
    train_reference_df = train_reference_df[:smoke_test_size]
    val_reference_df = val_reference_df[:smoke_test_size]

# Count the elements in the sets
num_train_data_normal = sum(train_reference_df['label'] == 0)
num_train_data_afib   = sum(train_reference_df['label'] == 1)
num_val_data_normal   = sum(val_reference_df['label'] == 0)
num_val_data_afib     = sum(val_reference_df['label'] == 1)

print('TRAIN SET')
print('\tNormal ECG: {} ({:.2f}%)'.format(num_train_data_normal, 100 * num_train_data_normal / len(train_reference_df)))
print('\tAfib ECG: {} ({:.2f}%)'.format(num_train_data_afib, 100 * num_train_data_afib / len(train_reference_df)))
print('VALIDATION SET')
print('\tNormal ECG: {} ({:.2f}%)'.format(num_val_data_normal, 100 * num_val_data_normal / len(val_reference_df)))
print('\tAfib ECG: {} ({:.2f}%)'.format(num_val_data_afib, 100 * num_val_data_afib / len(val_reference_df)))
# Out:
# TRAIN SET
# 	Normal ECG: 4061 (87.02%)
# 	Afib ECG: 606 (12.98%)
# VALIDATION SET
# 	Normal ECG: 1015 (86.98%)
# 	Afib ECG: 152 (13.02%)

# %% [markdown]
# **Expected Output**
#
# <table>
# <tr>
# <td>
#     TRAIN SET
#
# 	Normal ECG: 4061 (87.02%)
# 	Afib ECG: 606 (12.98%)
#
# </td>
# </tr>
# <tr>
# <td>
#     VALIDATION SET
#
# 	Normal ECG: 1015 (86.98%)
# 	Afib ECG: 152 (13.02%)
#
# </td>
# </tr>
# </table>

# %% [markdown]
# ### 1.5 - Load data
# Now we define a function to load the actual signals from the files. Data is stored as *.mat* files (MATLAB format). Python can easily load this data using the `loadmat` function from the scipy library ([doc here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.io.loadmat.html)).
#
# The function takes the complete path of the file to be loaded as input: it can be composed using the filename *file_name* and the data main directory *data_dir* (in our case *data*, defined at the beginning of the notebook). The complete path of the file will be:
# ```python
# file_mat = data_dir + '/' + file_name + '.mat'
# ```
# After loading it, you have to extract the specific field from the matlab file: use ```['val']``` after the execution of "loadmat(...)"
#
# An example of a normal sinus rhythm and an Afib is shown. As you can see, during atrial fibrillation the ECG exhibits a more irregular beating.
#
#  **NOTE**: The method *.decode()* is required because TensorFlow encodes string data as bytes object when it uses a custom python function, as you will use below. The *.decode()* method simply converts a sequence of bytes to a string (by default, UTF-8 will be used as standard character encoding).

# %%
def load_data(file_name, data_dir):
    if isinstance(data_dir, bytes):
        data_dir = data_dir.decode()
    if isinstance(file_name, bytes):
        file_name = file_name.decode()
    # Load the ECG signal from the .mat file
    file_mat = data_dir + '/' + file_name + '.mat'
    data = loadmat(file_mat)['val'].squeeze()
    return data.squeeze()

# Plot a Normal ECG
file_name = 'A00001'

# Call the function you defined above with the proper arguments (hint: we defined above the folder name as 'data_dir')
normal_data = load_data(file_name, data_dir)

plt.figure()
plt.plot(normal_data, color='b')
plt.xlim([4000, 7000])
plt.title('{} - Normal ECG'.format(file_name))

# Plot an Afib ECG
file_name = 'A08283'

# Call the function you define above with the proper arguments
afib_data = load_data(file_name, data_dir)

plt.figure()
plt.plot(afib_data, color='r')
plt.xlim([4000, 7000])
plt.title('{} - Afib ECG'.format(file_name))
# Out:
# Text(0.5, 1.0, 'A08283 - Afib ECG')

# %% [markdown]
# ### 1.6 - Preprocessing: baseline wander removal
# **Baseline wander** is a low-frequency artifact in the ECG that arises from several factors, such as breathing, electrically charged electrodes, or subject movement. In the ECG signal, it can be seen as a low-frequency trend, which is not related to the heart activity and should be removed.
#
# <img src="img/bwr.png" width="60%"/>
#
# Even though it may seem trivial, the preservation of the shape of the actual ECG is of primary importance, since it has components also in the low-frequency band.
#
# There are several ways to cope with this problem. Without going too much into the details, an easy way to do that is to use median filters (one with 0.2 seconds and one with 0.6 seconds window size) to estimate the baseline, and then remove it from the signal. We are going to use the `medfilt` function provided by scipy ([doc here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.medfilt.html)).
# You have to apply twice the filter using the different window sizes:
# ```python
# win_size = int(np.round(x_seconds * fs)) + 1
# baseline = medfilt(```filter input```, win_size)
# ```
#
#  As you can see, after the process the low electrical activity of the ECG is almost centered to zero.

# %%
def baseline_wander_removal(data):
    # Sampling frequency
    fs = 300
    # Baseline estimation
    win_size = int (np.round(0.25 * fs))
    baseline = medfilt(data, win_size)
    # Removing baseline
    filt_data = data - baseline

    return filt_data
    
# Example
file_name = 'A00001'

# Load the data and apply the baseline wander removal using the two helper function you implemented above
data = load_data(file_name, data_dir)
filt_data = baseline_wander_removal(data)

plt.figure()
plt.plot(data, color='b')
plt.title('{} - Before baseline wander removal'.format(file_name))
plt.figure()
plt.plot(filt_data, color='b')
plt.title('{} - After baseline wander removal'.format(file_name))
# Out:
# Text(0.5, 1.0, 'A00001 - After baseline wander removal')

# %% [markdown]
# ### 1.7 - Preprocessing: normalization
# **Normalization** is another important step. Depending on the subject, its skin resistivity, the quality of the electrical connection of the electrodes and many other factors, the amplitude of the ECG may be highly affected.
#
# In this case, since we are more interested in the shape of the signal than in its amplitude, we perform an element-wise normalization, which means that the normalization is applied independently on each trace.
#
# For this purpose, we simply estimate the signal amplitude using the 99th and the 5th percentile (to exclude some possible outliers, more robust compared with max/min when using real-world data) and normalize with respect to this value. Documentation [here](https://numpy.org/doc/stable/reference/generated/numpy.percentile.html).
#
#  The result is a signal that is almost in the range \[-1, 1\].

# %%
def normalize_data(data):
    # Amplitude estimate
    norm_factor = np.percentile(data, 99) - np.percentile(data, 5)
    return (data / norm_factor)
    
# Example
file_name = 'A00001'

# Load the data, apply the baseline wander removal and normalize the data using the three helper function you implemented above
data = load_data(file_name, data_dir)
filt_data = baseline_wander_removal(data)
norm_data = normalize_data(filt_data)

plt.figure()
plt.plot(filt_data, color='b')
plt.title('{} - Before normalization'.format(file_name))
plt.figure()
plt.plot(norm_data, color='b')
plt.title('{} - After normalization'.format(file_name))
# Out:
# Text(0.5, 1.0, 'A00001 - After normalization')

# %% [markdown]
#  ### 1.8 - Preprocessing: random crop
#  First, let's print the shapes of some of the training data (the first 50 elements).

# %%
for name in list(train_reference_df.iloc[:,0]):

    data = load_data(name.encode(), data_dir)
    print('File: {} - Shape: {}'.format(name, data.shape))
# Out:
# File: A02977 - Shape: (9000,)
# File: A05115 - Shape: (10196,)
# File: A07559 - Shape: (9000,)
# File: A01718 - Shape: (9000,)
# File: A08475 - Shape: (9000,)
# File: A00599 - Shape: (9000,)
# File: A05342 - Shape: (9000,)
# File: A02106 - Shape: (9000,)
# File: A03256 - Shape: (9000,)
# File: A06256 - Shape: (12748,)
# File: A06324 - Shape: (10434,)
# File: A01949 - Shape: (9000,)
# File: A04262 - Shape: (9000,)
# File: A02530 - Shape: (9000,)
# File: A02139 - Shape: (9000,)
# File: A01020 - Shape: (9000,)
# File: A08348 - Shape: (9000,)
# File: A03737 - Shape: (9000,)
# File: A01491 - Shape: (9000,)
# File: A08242 - Shape: (9000,)
# File: A00351 - Shape: (9000,)
# File: A05588 - Shape: (13920,)
# File: A05860 - Shape: (9126,)
# File: A04187 - Shape: (9000,)
# File: A03631 - Shape: (9000,)
# File: A04618 - Shape: (9000,)
# File: A02389 - Shape: (9000,)
# File: A06406 - Shape: (9000,)
# File: A05988 - Shape: (9000,)
# File: A02584 - Shape: (9000,)
# File: A00836 - Shape: (9000,)
# File: A07780 - Shape: (9000,)
# File: A01492 - Shape: (8902,)
# File: A07792 - Shape: (9000,)
# File: A05498 - Shape: (9000,)
# File: A04672 - Shape: (9000,)
# File: A00267 - Shape: (9000,)
# File: A00447 - Shape: (9000,)
# File: A07042 - Shape: (5260,)
# File: A02925 - Shape: (9000,)
# File: A04048 - Shape: (9000,)
# File: A06778 - Shape: (9000,)
# File: A08113 - Shape: (9000,)
# File: A07449 - Shape: (9000,)
# File: A03460 - Shape: (3300,)
# File: A02086 - Shape: (9000,)
# File: A04655 - Shape: (9000,)
# File: A02778 - Shape: (9000,)
# File: A04392 - Shape: (9000,)
# File: A02907 - Shape: (18000,)
# File: A00854 - Shape: (9000,)
# File: A01553 - Shape: (6406,)
# File: A03120 - Shape: (18000,)
# File: A05545 - Shape: (9000,)
# File: A07693 - Shape: (9000,)
# File: A03699 - Shape: (9000,)
# File: A03555 - Shape: (6016,)
# File: A08238 - Shape: (3912,)
# File: A02199 - Shape: (4040,)
# File: A00374 - Shape: (9000,)
# File: A03068 - Shape: (16116,)
# File: A03243 - Shape: (9000,)
# File: A08408 - Shape: (9000,)
# File: A08137 - Shape: (9000,)
# File: A04669 - Shape: (9000,)
# File: A03647 - Shape: (9000,)
# File: A06079 - Shape: (9000,)
# File: A08395 - Shape: (9000,)
# File: A05380 - Shape: (9000,)
# File: A05670 - Shape: (9000,)
# File: A04070 - Shape: (9298,)
# File: A01347 - Shape: (9000,)
# File: A06258 - Shape: (9000,)
# File: A04631 - Shape: (9000,)
# File: A04447 - Shape: (9000,)
# File: A03307 - Shape: (9000,)
# File: A02579 - Shape: (18000,)
# File: A04248 - Shape: (9000,)
# File: A02894 - Shape: (9000,)
# File: A00778 - Shape: (9000,)
# File: A03922 - Shape: (9000,)
# File: A07784 - Shape: (4072,)
# File: A05212 - Shape: (9000,)
# File: A07334 - Shape: (9000,)
# File: A03159 - Shape: (9000,)
# File: A03547 - Shape: (9000,)
# File: A01551 - Shape: (9000,)
# File: A08362 - Shape: (9000,)
# File: A04300 - Shape: (6940,)
# File: A08421 - Shape: (9000,)
# File: A02264 - Shape: (9000,)
# File: A01614 - Shape: (9000,)
# File: A05662 - Shape: (12996,)
# File: A03231 - Shape: (9000,)
# File: A01980 - Shape: (9000,)
# File: A00841 - Shape: (9000,)
# File: A02319 - Shape: (9000,)
# File: A08282 - Shape: (5548,)
# File: A02009 - Shape: (9000,)
# File: A07738 - Shape: (9000,)
# File: A08306 - Shape: (9000,)
# File: A07225 - Shape: (9000,)
# File: A06461 - Shape: (9000,)
# File: A01278 - Shape: (9000,)
# File: A02670 - Shape: (9000,)
# File: A08289 - Shape: (9000,)
# File: A06581 - Shape: (4396,)
# File: A06070 - Shape: (9000,)
# File: A08330 - Shape: (4682,)
# File: A00137 - Shape: (9000,)
# File: A05159 - Shape: (18000,)
# File: A05891 - Shape: (10424,)
# File: A02472 - Shape: (9000,)
# File: A07927 - Shape: (9000,)
# File: A06120 - Shape: (9514,)
# File: A07870 - Shape: (6210,)
# File: A04379 - Shape: (3774,)
# File: A06308 - Shape: (17614,)
# File: A07839 - Shape: (9000,)
# File: A00972 - Shape: (18000,)
# File: A07835 - Shape: (9000,)
# File: A07082 - Shape: (9000,)
# File: A04373 - Shape: (9000,)
# File: A02130 - Shape: (9000,)
# File: A00322 - Shape: (9000,)
# File: A04051 - Shape: (9000,)
# File: A04746 - Shape: (3664,)
# File: A00192 - Shape: (9000,)
# File: A08145 - Shape: (9000,)
# File: A00528 - Shape: (9000,)
# File: A06929 - Shape: (9000,)
# File: A06075 - Shape: (11234,)
# File: A05772 - Shape: (11686,)
# File: A00555 - Shape: (9592,)
# File: A06937 - Shape: (9000,)
# File: A06149 - Shape: (11700,)
# File: A04974 - Shape: (9000,)
# File: A05104 - Shape: (9000,)
# File: A02099 - Shape: (9000,)
# File: A06943 - Shape: (9000,)
# File: A06215 - Shape: (11304,)
# File: A07619 - Shape: (9000,)
# File: A07953 - Shape: (8968,)
# File: A06167 - Shape: (10214,)
# File: A01747 - Shape: (9000,)
# File: A07844 - Shape: (9000,)
# File: A00239 - Shape: (5288,)
# File: A03359 - Shape: (9000,)
# File: A02142 - Shape: (18000,)
# File: A07371 - Shape: (9000,)
# File: A04711 - Shape: (7020,)
# File: A06138 - Shape: (9000,)
# File: A06088 - Shape: (11928,)
# File: A05246 - Shape: (9000,)
# File: A02776 - Shape: (18000,)
# File: A08080 - Shape: (9000,)
# File: A02923 - Shape: (9000,)
# File: A04687 - Shape: (11680,)
# File: A00405 - Shape: (3020,)
# File: A07022 - Shape: (9000,)
# File: A02013 - Shape: (9000,)
# File: A07463 - Shape: (9000,)
# File: A04484 - Shape: (7802,)
# File: A03909 - Shape: (18000,)
# File: A07343 - Shape: (9000,)
# File: A05672 - Shape: (9000,)
# File: A00160 - Shape: (9000,)
# File: A04218 - Shape: (9000,)
# File: A05000 - Shape: (9000,)
# File: A00265 - Shape: (9000,)
# File: A06360 - Shape: (9000,)
# File: A01360 - Shape: (9000,)
# File: A04894 - Shape: (9000,)
# File: A04442 - Shape: (6038,)
# File: A08403 - Shape: (9000,)
# File: A00601 - Shape: (5718,)
# File: A07860 - Shape: (3310,)
# File: A01710 - Shape: (9000,)
# File: A05777 - Shape: (10256,)
# File: A04022 - Shape: (9000,)
# File: A04337 - Shape: (9000,)
# File: A01111 - Shape: (18000,)
# File: A01272 - Shape: (9000,)
# File: A01593 - Shape: (9000,)
# File: A03801 - Shape: (9000,)
# File: A00548 - Shape: (3846,)
# File: A02407 - Shape: (9000,)
# File: A05445 - Shape: (9000,)
# File: A02321 - Shape: (9000,)
# File: A05533 - Shape: (4898,)
# File: A07690 - Shape: (9000,)
# File: A01666 - Shape: (9000,)
# File: A00552 - Shape: (12310,)
# File: A07432 - Shape: (4036,)
# File: A05587 - Shape: (16928,)
# File: A02293 - Shape: (9000,)
# File: A01697 - Shape: (9000,)
# File: A07698 - Shape: (7360,)
# File: A01901 - Shape: (9000,)
# File: A02312 - Shape: (3024,)
# File: A04629 - Shape: (9996,)
# File: A03502 - Shape: (9000,)
# File: A03843 - Shape: (9000,)
# File: A02051 - Shape: (9000,)
# File: A02376 - Shape: (9000,)
# File: A04691 - Shape: (18000,)
# File: A05866 - Shape: (9438,)
# File: A00386 - Shape: (9000,)
# File: A05082 - Shape: (18000,)
# File: A03783 - Shape: (9000,)
# File: A00812 - Shape: (9000,)
# File: A02686 - Shape: (9000,)
# File: A05279 - Shape: (9000,)
# File: A00073 - Shape: (9000,)
# File: A07123 - Shape: (9000,)
# File: A08296 - Shape: (3204,)
# File: A06951 - Shape: (9000,)
# File: A06990 - Shape: (9000,)
# File: A04030 - Shape: (9000,)
# File: A00581 - Shape: (9000,)
# File: A03568 - Shape: (18000,)
# File: A03503 - Shape: (9000,)
# File: A06707 - Shape: (9000,)
# File: A07094 - Shape: (5572,)
# File: A06263 - Shape: (18140,)
# File: A07955 - Shape: (9000,)
# File: A02991 - Shape: (9000,)
# File: A04398 - Shape: (4072,)
# File: A01778 - Shape: (9000,)
# File: A00478 - Shape: (9000,)
# File: A03748 - Shape: (9000,)
# File: A06315 - Shape: (10920,)
# File: A02616 - Shape: (9000,)
# File: A08368 - Shape: (9000,)
# File: A02346 - Shape: (9000,)
# File: A05979 - Shape: (12340,)
# File: A04525 - Shape: (6988,)
# File: A00625 - Shape: (9000,)
# File: A05534 - Shape: (9000,)
# File: A07970 - Shape: (9000,)
# File: A01128 - Shape: (9000,)
# File: A04201 - Shape: (9000,)
# File: A07089 - Shape: (9030,)
# File: A01277 - Shape: (7458,)
# File: A07470 - Shape: (9000,)
# File: A00042 - Shape: (9000,)
# File: A03885 - Shape: (9000,)
# File: A07582 - Shape: (9000,)
# File: A02671 - Shape: (9000,)
# File: A05547 - Shape: (9000,)
# File: A04128 - Shape: (9000,)
# File: A00315 - Shape: (9000,)
# File: A03438 - Shape: (9000,)
# File: A02378 - Shape: (7306,)
# File: A02749 - Shape: (9000,)
# File: A04481 - Shape: (9000,)
# File: A07011 - Shape: (9000,)
# File: A03982 - Shape: (15626,)
# File: A04095 - Shape: (9000,)
# File: A07116 - Shape: (9000,)
# File: A01599 - Shape: (9000,)
# File: A02406 - Shape: (9000,)
# File: A02146 - Shape: (9000,)
# File: A01762 - Shape: (9000,)
# File: A07272 - Shape: (9000,)
# File: A06663 - Shape: (9000,)
# File: A00227 - Shape: (9000,)
# File: A06593 - Shape: (9000,)
# File: A07090 - Shape: (9000,)
# File: A08290 - Shape: (9000,)
# File: A02160 - Shape: (9000,)
# File: A03353 - Shape: (9000,)
# File: A03428 - Shape: (9000,)
# File: A03279 - Shape: (9000,)
# File: A05391 - Shape: (8114,)
# File: A00172 - Shape: (9000,)
# File: A07515 - Shape: (9000,)
# File: A06045 - Shape: (9000,)
# File: A01411 - Shape: (9000,)
# File: A05255 - Shape: (7634,)
# File: A04056 - Shape: (9000,)
# File: A07812 - Shape: (9000,)
# File: A06097 - Shape: (9000,)
# File: A07165 - Shape: (9000,)
# File: A07059 - Shape: (18000,)
# File: A05179 - Shape: (9000,)
# File: A04065 - Shape: (9000,)
# File: A00592 - Shape: (2996,)
# File: A05536 - Shape: (18000,)
# File: A08328 - Shape: (9552,)
# File: A01848 - Shape: (9000,)
# File: A02275 - Shape: (9000,)
# File: A01782 - Shape: (9000,)
# File: A07351 - Shape: (18000,)
# File: A02344 - Shape: (9000,)
# File: A08308 - Shape: (9000,)
# File: A06053 - Shape: (14372,)
# File: A02526 - Shape: (9000,)
# File: A07770 - Shape: (9000,)
# File: A02657 - Shape: (9000,)
# File: A01628 - Shape: (9000,)
# File: A00134 - Shape: (9000,)
# File: A02403 - Shape: (9000,)
# File: A07294 - Shape: (9000,)
# File: A04091 - Shape: (9000,)
# File: A02154 - Shape: (9000,)
# File: A01851 - Shape: (9000,)
# File: A05433 - Shape: (9000,)
# File: A03731 - Shape: (9000,)
# File: A07646 - Shape: (9000,)
# File: A00658 - Shape: (9000,)
# File: A06011 - Shape: (12832,)
# File: A05290 - Shape: (18000,)
# File: A02345 - Shape: (2870,)
# File: A02082 - Shape: (9000,)
# File: A06230 - Shape: (14788,)
# File: A06518 - Shape: (9000,)
# File: A03061 - Shape: (9000,)
# File: A07080 - Shape: (18000,)
# File: A01064 - Shape: (3436,)
# File: A03301 - Shape: (9000,)
# File: A04239 - Shape: (2812,)
# File: A02040 - Shape: (9000,)
# File: A06924 - Shape: (9000,)
# File: A03289 - Shape: (9000,)
# File: A02335 - Shape: (9000,)
# File: A07253 - Shape: (9000,)
# File: A03086 - Shape: (7438,)
# File: A05456 - Shape: (9000,)
# File: A02061 - Shape: (9000,)
# File: A02327 - Shape: (9000,)
# File: A04394 - Shape: (9000,)
# File: A00099 - Shape: (9000,)
# File: A06944 - Shape: (9000,)
# File: A01344 - Shape: (9000,)
# File: A06294 - Shape: (9930,)
# File: A02898 - Shape: (18000,)
# File: A07612 - Shape: (9000,)
# File: A05202 - Shape: (9000,)
# File: A01920 - Shape: (9000,)
# File: A02946 - Shape: (9000,)
# File: A00361 - Shape: (9000,)
# File: A05431 - Shape: (9000,)
# File: A06906 - Shape: (9000,)
# File: A05226 - Shape: (9000,)
# File: A03281 - Shape: (9000,)
# File: A07795 - Shape: (9000,)
# File: A02851 - Shape: (7978,)
# File: A03860 - Shape: (9000,)
# File: A02641 - Shape: (9000,)
# File: A03998 - Shape: (9000,)
# File: A02394 - Shape: (3166,)
# File: A01249 - Shape: (9000,)
# File: A05460 - Shape: (9000,)
# File: A07516 - Shape: (9000,)
# File: A06610 - Shape: (9000,)
# File: A07995 - Shape: (9000,)
# File: A06536 - Shape: (18000,)
# File: A00060 - Shape: (14054,)
# File: A08477 - Shape: (9000,)
# File: A03206 - Shape: (9000,)
# File: A06550 - Shape: (9000,)
# File: A08461 - Shape: (9000,)
# File: A07204 - Shape: (9000,)
# File: A03818 - Shape: (9000,)
# File: A03190 - Shape: (9000,)
# File: A05508 - Shape: (9000,)
# File: A00349 - Shape: (9000,)
# File: A03819 - Shape: (9000,)
# File: A00720 - Shape: (6140,)
# File: A03323 - Shape: (9000,)
# File: A05459 - Shape: (4386,)
# File: A01499 - Shape: (9000,)
# File: A00641 - Shape: (18000,)
# File: A01817 - Shape: (9000,)
# File: A07317 - Shape: (9000,)
# File: A02564 - Shape: (9000,)
# File: A07957 - Shape: (3280,)
# File: A00578 - Shape: (9000,)
# File: A02384 - Shape: (9000,)
# File: A08169 - Shape: (9000,)
# File: A01579 - Shape: (9000,)
# File: A02448 - Shape: (4062,)
# File: A07075 - Shape: (9000,)
# File: A00063 - Shape: (18000,)
# File: A05543 - Shape: (9000,)
# File: A07028 - Shape: (4938,)
# File: A03507 - Shape: (3384,)
# File: A07291 - Shape: (9000,)
# File: A04068 - Shape: (9000,)
# File: A06567 - Shape: (5256,)
# File: A01793 - Shape: (9000,)
# File: A02892 - Shape: (9000,)
# File: A00915 - Shape: (9000,)
# File: A03712 - Shape: (9000,)
# File: A05550 - Shape: (9000,)
# File: A01259 - Shape: (9000,)
# File: A03896 - Shape: (9000,)
# File: A05617 - Shape: (16316,)
# File: A07626 - Shape: (9000,)
# File: A07847 - Shape: (9000,)
# File: A07552 - Shape: (9000,)
# File: A03175 - Shape: (18000,)
# File: A05535 - Shape: (9000,)
# File: A05948 - Shape: (17488,)
# File: A08397 - Shape: (9000,)
# File: A01967 - Shape: (9000,)
# File: A01161 - Shape: (9000,)
# File: A01446 - Shape: (12610,)
# File: A00715 - Shape: (9000,)
# File: A00178 - Shape: (3238,)
# File: A02817 - Shape: (9000,)
# File: A07647 - Shape: (9000,)
# File: A04516 - Shape: (9000,)
# File: A03227 - Shape: (9000,)
# File: A04530 - Shape: (3704,)
# File: A07828 - Shape: (9000,)
# File: A04961 - Shape: (9000,)
# File: A04097 - Shape: (9000,)
# File: A06750 - Shape: (9000,)
# File: A01691 - Shape: (9000,)
# File: A08346 - Shape: (9000,)
# File: A07019 - Shape: (9000,)
# File: A01464 - Shape: (9000,)
# File: A02405 - Shape: (9000,)
# File: A06972 - Shape: (9000,)
# File: A02906 - Shape: (9000,)
# File: A05264 - Shape: (9000,)
# File: A00729 - Shape: (9000,)
# File: A06836 - Shape: (9000,)
# File: A05878 - Shape: (12770,)
# File: A03012 - Shape: (9000,)
# File: A06861 - Shape: (9000,)
# File: A04107 - Shape: (18000,)
# File: A03815 - Shape: (9000,)
# File: A00645 - Shape: (9000,)
# File: A03520 - Shape: (9000,)
# File: A07385 - Shape: (9000,)
# File: A00527 - Shape: (9000,)
# File: A05136 - Shape: (9000,)
# File: A08088 - Shape: (9000,)
# File: A02038 - Shape: (9000,)
# File: A08384 - Shape: (4136,)
# File: A04934 - Shape: (3826,)
# File: A06522 - Shape: (9000,)
# File: A01760 - Shape: (9000,)
# File: A01284 - Shape: (9000,)
# File: A04880 - Shape: (18000,)
# File: A05952 - Shape: (9000,)
# File: A03715 - Shape: (9000,)
# File: A03688 - Shape: (13398,)
# File: A08026 - Shape: (9000,)
# File: A05335 - Shape: (15638,)
# File: A03442 - Shape: (9000,)
# File: A00184 - Shape: (9000,)
# File: A05011 - Shape: (18000,)
# File: A06547 - Shape: (8114,)
# File: A01362 - Shape: (9000,)
# File: A04885 - Shape: (9000,)
# File: A05890 - Shape: (11254,)
# File: A01887 - Shape: (9000,)
# File: A05810 - Shape: (9000,)
# File: A03707 - Shape: (3494,)
# File: A06442 - Shape: (5412,)
# File: A04420 - Shape: (9000,)
# File: A06865 - Shape: (9000,)
# File: A07004 - Shape: (9000,)
# File: A00568 - Shape: (9000,)
# File: A06777 - Shape: (9000,)
# File: A03679 - Shape: (9000,)
# File: A03891 - Shape: (3538,)
# File: A05717 - Shape: (10564,)
# File: A07849 - Shape: (9000,)
# File: A00995 - Shape: (9000,)
# File: A03824 - Shape: (9000,)
# File: A01687 - Shape: (9000,)
# File: A04273 - Shape: (9000,)
# File: A01930 - Shape: (9000,)
# File: A05859 - Shape: (9000,)
# File: A01032 - Shape: (9000,)
# File: A02664 - Shape: (9000,)
# File: A02373 - Shape: (9000,)
# File: A06286 - Shape: (10494,)
# File: A03034 - Shape: (18000,)
# File: A01818 - Shape: (9000,)
# File: A08064 - Shape: (9000,)
# File: A00590 - Shape: (9000,)
# File: A05169 - Shape: (9000,)
# File: A01096 - Shape: (9000,)
# File: A03526 - Shape: (9000,)
# File: A00479 - Shape: (9000,)
# File: A05936 - Shape: (11522,)
# File: A07365 - Shape: (9000,)
# File: A00843 - Shape: (9000,)
# File: A01240 - Shape: (9000,)
# File: A06689 - Shape: (9000,)
# File: A07117 - Shape: (18000,)
# File: A00419 - Shape: (18000,)
# File: A05512 - Shape: (9000,)
# File: A07673 - Shape: (18000,)
# File: A04317 - Shape: (9000,)
# File: A08023 - Shape: (9000,)
# File: A04069 - Shape: (9000,)
# File: A05085 - Shape: (9000,)
# File: A08240 - Shape: (9000,)
# File: A07735 - Shape: (9000,)
# File: A05008 - Shape: (9000,)
# File: A05387 - Shape: (9000,)
# File: A07507 - Shape: (9000,)
# File: A04206 - Shape: (9000,)
# File: A07479 - Shape: (4878,)
# File: A06354 - Shape: (9000,)
# File: A02520 - Shape: (9000,)
# File: A06568 - Shape: (9000,)
# File: A07991 - Shape: (9000,)
# File: A00795 - Shape: (9000,)
# File: A02424 - Shape: (9000,)
# File: A01456 - Shape: (9000,)
# File: A07722 - Shape: (9000,)
# File: A00929 - Shape: (18000,)
# File: A02030 - Shape: (9000,)
# File: A03027 - Shape: (18000,)
# File: A07174 - Shape: (9000,)
# File: A00015 - Shape: (6102,)
# File: A05061 - Shape: (9000,)
# File: A06206 - Shape: (9668,)
# File: A04027 - Shape: (9000,)
# File: A08150 - Shape: (10114,)
# File: A00733 - Shape: (9000,)
# File: A04438 - Shape: (9000,)
# File: A01022 - Shape: (9000,)
# File: A00667 - Shape: (9000,)
# File: A01109 - Shape: (9000,)
# File: A08186 - Shape: (9000,)
# File: A02267 - Shape: (9000,)
# File: A05649 - Shape: (9000,)
# File: A05334 - Shape: (9000,)
# File: A04141 - Shape: (9000,)
# File: A05465 - Shape: (9000,)
# File: A07607 - Shape: (7247,)
# File: A02124 - Shape: (18000,)
# File: A05862 - Shape: (13186,)
# File: A01963 - Shape: (9000,)
# File: A04490 - Shape: (18000,)
# File: A00439 - Shape: (18000,)
# File: A04295 - Shape: (9000,)
# File: A01995 - Shape: (9000,)
# File: A08469 - Shape: (9000,)
# File: A02703 - Shape: (9000,)
# File: A05675 - Shape: (9864,)
# File: A05263 - Shape: (9000,)
# File: A03988 - Shape: (9000,)
# File: A03147 - Shape: (9000,)
# File: A01957 - Shape: (9000,)
# File: A03198 - Shape: (9000,)
# File: A08065 - Shape: (9000,)
# File: A03523 - Shape: (9000,)
# File: A07186 - Shape: (9000,)
# File: A04696 - Shape: (18000,)
# File: A02020 - Shape: (9000,)
# File: A08143 - Shape: (9000,)
# File: A00350 - Shape: (9000,)
# File: A02858 - Shape: (6468,)
# File: A02473 - Shape: (7242,)
# File: A04004 - Shape: (9000,)
# File: A07623 - Shape: (9000,)
# File: A02731 - Shape: (9000,)
# File: A04712 - Shape: (9000,)
# File: A00701 - Shape: (4692,)
# File: A04193 - Shape: (9000,)
# File: A01623 - Shape: (9000,)
# File: A00652 - Shape: (18000,)
# File: A01906 - Shape: (9000,)
# File: A02489 - Shape: (9000,)
# File: A03917 - Shape: (9000,)
# File: A07685 - Shape: (9000,)
# File: A00079 - Shape: (9000,)
# File: A00763 - Shape: (4468,)
# File: A00249 - Shape: (9000,)
# File: A00739 - Shape: (9000,)
# File: A05254 - Shape: (9000,)
# File: A02856 - Shape: (5702,)
# File: A01138 - Shape: (9000,)
# File: A01843 - Shape: (9000,)
# File: A01837 - Shape: (18000,)
# File: A04450 - Shape: (18000,)
# File: A08115 - Shape: (9000,)
# File: A01969 - Shape: (9000,)
# File: A04364 - Shape: (9000,)
# File: A05235 - Shape: (3690,)
# File: A06961 - Shape: (9000,)
# File: A05173 - Shape: (9000,)
# File: A03187 - Shape: (18000,)
# File: A02735 - Shape: (9000,)
# File: A01882 - Shape: (9000,)
# File: A07434 - Shape: (9000,)
# File: A02109 - Shape: (9000,)
# File: A00794 - Shape: (9000,)
# File: A01823 - Shape: (8294,)
# File: A03253 - Shape: (3836,)
# File: A06828 - Shape: (9000,)
# File: A05284 - Shape: (9000,)
# File: A03774 - Shape: (9000,)
# File: A02959 - Shape: (9000,)
# File: A01243 - Shape: (9000,)
# File: A04211 - Shape: (18000,)
# File: A04090 - Shape: (9000,)
# File: A01442 - Shape: (9000,)
# File: A04100 - Shape: (9000,)
# File: A08057 - Shape: (7350,)
# File: A01319 - Shape: (9000,)
# File: A03340 - Shape: (9000,)
# File: A07747 - Shape: (8180,)
# File: A06484 - Shape: (9000,)
# File: A01053 - Shape: (9000,)
# File: A07424 - Shape: (9000,)
# File: A03146 - Shape: (9000,)
# File: A04856 - Shape: (9000,)
# File: A04690 - Shape: (9000,)
# File: A07078 - Shape: (9000,)
# File: A07088 - Shape: (9000,)
# File: A08363 - Shape: (9000,)
# File: A00387 - Shape: (9000,)
# File: A01449 - Shape: (9000,)
# File: A02786 - Shape: (3814,)
# File: A01738 - Shape: (9000,)
# File: A02237 - Shape: (9000,)
# File: A07143 - Shape: (9000,)
# File: A05621 - Shape: (14210,)
# File: A01033 - Shape: (9000,)
# File: A07744 - Shape: (8324,)
# File: A02547 - Shape: (9000,)
# File: A01370 - Shape: (9000,)
# File: A05976 - Shape: (9000,)
# File: A03132 - Shape: (5868,)
# File: A07573 - Shape: (9000,)
# File: A07932 - Shape: (18000,)
# File: A07862 - Shape: (9000,)
# File: A00890 - Shape: (9000,)
# File: A07031 - Shape: (9000,)
# File: A02668 - Shape: (9000,)
# File: A04990 - Shape: (9000,)
# File: A07962 - Shape: (4038,)
# File: A01717 - Shape: (9000,)
# File: A04404 - Shape: (9000,)
# File: A03827 - Shape: (9000,)
# File: A02071 - Shape: (18000,)
# File: A02481 - Shape: (18000,)
# File: A05761 - Shape: (10636,)
# File: A02501 - Shape: (17366,)
# File: A04017 - Shape: (9000,)
# File: A02837 - Shape: (9000,)
# File: A08447 - Shape: (9000,)
# File: A00166 - Shape: (9000,)
# File: A02382 - Shape: (18000,)
# File: A05098 - Shape: (9000,)
# File: A07205 - Shape: (9000,)
# File: A01979 - Shape: (9000,)
# File: A03317 - Shape: (9000,)
# File: A06575 - Shape: (9000,)
# File: A05544 - Shape: (9000,)
# File: A00425 - Shape: (8686,)
# File: A06443 - Shape: (9000,)
# File: A02929 - Shape: (8256,)
# File: A06091 - Shape: (10756,)
# File: A06528 - Shape: (9000,)
# File: A07613 - Shape: (9000,)
# File: A03232 - Shape: (9000,)
# File: A07694 - Shape: (9000,)
# File: A02083 - Shape: (9000,)
# File: A00219 - Shape: (9000,)
# File: A02241 - Shape: (9000,)
# File: A01086 - Shape: (9000,)
# File: A04009 - Shape: (9000,)
# File: A02618 - Shape: (9000,)
# File: A00558 - Shape: (8636,)
# File: A04928 - Shape: (9000,)
# File: A01488 - Shape: (9000,)
# File: A05755 - Shape: (9000,)
# File: A02064 - Shape: (9000,)
# File: A01377 - Shape: (9000,)
# File: A02659 - Shape: (4386,)
# File: A06495 - Shape: (6836,)
# File: A04380 - Shape: (6752,)
# File: A07079 - Shape: (9000,)
# File: A03042 - Shape: (12150,)
# File: A01254 - Shape: (18000,)
# File: A04740 - Shape: (9000,)
# File: A07512 - Shape: (9000,)
# File: A03949 - Shape: (9000,)
# File: A00004 - Shape: (9000,)
# File: A01812 - Shape: (7044,)
# File: A04146 - Shape: (9000,)
# File: A08298 - Shape: (18000,)
# File: A03877 - Shape: (9000,)
# File: A04617 - Shape: (9000,)
# File: A02179 - Shape: (2832,)
# File: A02435 - Shape: (9000,)
# File: A08195 - Shape: (4280,)
# File: A04866 - Shape: (9000,)
# File: A02191 - Shape: (9000,)
# File: A04455 - Shape: (9000,)
# File: A03085 - Shape: (9000,)
# File: A05554 - Shape: (9000,)
# File: A07167 - Shape: (9000,)
# File: A04207 - Shape: (9000,)
# File: A01845 - Shape: (9000,)
# File: A05193 - Shape: (3740,)
# File: A05196 - Shape: (9000,)
# File: A01877 - Shape: (9000,)
# File: A01609 - Shape: (9000,)
# File: A02592 - Shape: (9000,)
# File: A00730 - Shape: (9000,)
# File: A02126 - Shape: (3198,)
# File: A07054 - Shape: (9000,)
# File: A07669 - Shape: (9000,)
# File: A01432 - Shape: (9000,)
# File: A01898 - Shape: (9000,)
# File: A06805 - Shape: (7988,)
# File: A03926 - Shape: (9000,)
# File: A08001 - Shape: (9000,)
# File: A04843 - Shape: (9000,)
# File: A07353 - Shape: (9000,)
# File: A00610 - Shape: (5472,)
# File: A02250 - Shape: (9000,)
# File: A05287 - Shape: (9000,)
# File: A05168 - Shape: (9000,)
# File: A00179 - Shape: (9000,)
# File: A03144 - Shape: (9000,)
# File: A06576 - Shape: (9000,)
# File: A02755 - Shape: (9000,)
# File: A05221 - Shape: (9000,)
# File: A06913 - Shape: (9000,)
# File: A00507 - Shape: (9000,)
# File: A01074 - Shape: (9000,)
# File: A04935 - Shape: (9000,)
# File: A00276 - Shape: (9000,)
# File: A01139 - Shape: (9000,)
# File: A00258 - Shape: (5288,)
# File: A00059 - Shape: (18000,)
# File: A04538 - Shape: (5078,)
# File: A07239 - Shape: (18000,)
# File: A04410 - Shape: (9000,)
# File: A06342 - Shape: (9000,)
# File: A00182 - Shape: (18000,)
# File: A00781 - Shape: (4028,)
# File: A00128 - Shape: (7028,)
# File: A07525 - Shape: (9000,)
# File: A02603 - Shape: (9000,)
# File: A01339 - Shape: (9000,)
# File: A06833 - Shape: (9000,)
# File: A03673 - Shape: (9000,)
# File: A02357 - Shape: (9000,)
# File: A07259 - Shape: (6160,)
# File: A06450 - Shape: (9000,)
# File: A02427 - Shape: (9000,)
# File: A01603 - Shape: (9000,)
# File: A04121 - Shape: (9000,)
# File: A02039 - Shape: (9000,)
# File: A04549 - Shape: (15224,)
# File: A01741 - Shape: (9000,)
# File: A01694 - Shape: (9000,)
# File: A03261 - Shape: (9000,)
# File: A06702 - Shape: (9000,)
# File: A07264 - Shape: (9000,)
# File: A05581 - Shape: (9000,)
# File: A00081 - Shape: (18000,)
# File: A07901 - Shape: (9000,)
# File: A01688 - Shape: (6816,)
# File: A06469 - Shape: (9000,)
# File: A07315 - Shape: (9000,)
# File: A06058 - Shape: (9000,)
# File: A04342 - Shape: (9000,)
# File: A05007 - Shape: (6810,)
# File: A06815 - Shape: (18000,)
# File: A03134 - Shape: (9000,)
# File: A07586 - Shape: (16478,)
# File: A02095 - Shape: (5042,)
# File: A00881 - Shape: (9000,)
# File: A03613 - Shape: (9000,)
# File: A01451 - Shape: (9000,)
# File: A03979 - Shape: (9000,)
# File: A03992 - Shape: (9000,)
# File: A02338 - Shape: (9000,)
# File: A01715 - Shape: (5206,)
# File: A07576 - Shape: (6096,)
# File: A04624 - Shape: (9000,)
# File: A02260 - Shape: (9000,)
# File: A08089 - Shape: (9000,)
# File: A00620 - Shape: (3858,)
# File: A00472 - Shape: (9000,)
# File: A02089 - Shape: (18116,)
# File: A02795 - Shape: (9000,)
# File: A04988 - Shape: (3282,)
# File: A05499 - Shape: (2742,)
# File: A05669 - Shape: (9492,)
# File: A02043 - Shape: (9000,)
# File: A02707 - Shape: (9000,)
# File: A04188 - Shape: (9000,)
# File: A03954 - Shape: (9000,)
# File: A04270 - Shape: (9000,)
# File: A00435 - Shape: (9000,)
# File: A00371 - Shape: (9000,)
# File: A06980 - Shape: (9000,)
# File: A05330 - Shape: (9000,)
# File: A08340 - Shape: (9000,)
# File: A01985 - Shape: (9000,)
# File: A03382 - Shape: (18000,)
# File: A07347 - Shape: (9000,)
# File: A02548 - Shape: (9000,)
# File: A01447 - Shape: (18000,)
# File: A07530 - Shape: (9000,)
# File: A04610 - Shape: (9000,)
# File: A00132 - Shape: (9000,)
# File: A05963 - Shape: (9214,)
# File: A01870 - Shape: (8144,)
# File: A02508 - Shape: (9000,)
# File: A07668 - Shape: (9000,)
# File: A01482 - Shape: (9000,)
# File: A02413 - Shape: (12126,)
# File: A03429 - Shape: (5868,)
# File: A00685 - Shape: (15266,)
# File: A00254 - Shape: (9000,)
# File: A00680 - Shape: (9000,)
# File: A00149 - Shape: (9000,)
# File: A08235 - Shape: (9814,)
# File: A02797 - Shape: (8424,)
# File: A04333 - Shape: (9000,)
# File: A07164 - Shape: (9000,)
# File: A03713 - Shape: (9000,)
# File: A00247 - Shape: (9000,)
# File: A00595 - Shape: (9000,)
# File: A01854 - Shape: (18000,)
# File: A06858 - Shape: (9000,)
# File: A05474 - Shape: (9000,)
# File: A06482 - Shape: (9000,)
# File: A05185 - Shape: (9000,)
# File: A03164 - Shape: (9000,)
# File: A05513 - Shape: (9000,)
# File: A05218 - Shape: (18000,)
# File: A02698 - Shape: (9000,)
# File: A02981 - Shape: (9000,)
# File: A05157 - Shape: (9000,)
# File: A06151 - Shape: (10130,)
# File: A03384 - Shape: (9000,)
# File: A06279 - Shape: (9480,)
# File: A01988 - Shape: (9000,)
# File: A02913 - Shape: (5940,)
# File: A08448 - Shape: (7516,)
# File: A00504 - Shape: (5544,)
# File: A02456 - Shape: (9000,)
# File: A08462 - Shape: (18000,)
# File: A05296 - Shape: (9000,)
# File: A01799 - Shape: (9000,)
# File: A01538 - Shape: (9000,)
# File: A08072 - Shape: (18000,)
# File: A05177 - Shape: (3584,)
# File: A07832 - Shape: (9000,)
# File: A02660 - Shape: (9000,)
# File: A07846 - Shape: (9000,)
# File: A00965 - Shape: (9000,)
# File: A05118 - Shape: (18000,)
# File: A06580 - Shape: (9000,)
# File: A03720 - Shape: (5848,)
# File: A00366 - Shape: (9000,)
# File: A04726 - Shape: (9000,)
# File: A03709 - Shape: (9000,)
# File: A07822 - Shape: (9000,)
# File: A08106 - Shape: (9000,)
# File: A06734 - Shape: (18000,)
# File: A07041 - Shape: (9000,)
# File: A03407 - Shape: (18000,)
# File: A04050 - Shape: (9000,)
# File: A02857 - Shape: (9000,)
# File: A00341 - Shape: (9000,)
# File: A01376 - Shape: (9000,)
# File: A04587 - Shape: (9000,)
# File: A03188 - Shape: (9000,)
# File: A01759 - Shape: (9000,)
# File: A02416 - Shape: (18000,)
# File: A08044 - Shape: (18000,)
# File: A03131 - Shape: (9000,)
# File: A02774 - Shape: (9000,)
# File: A02539 - Shape: (9000,)
# File: A05021 - Shape: (9000,)
# File: A04307 - Shape: (9000,)
# File: A04169 - Shape: (9000,)
# File: A04388 - Shape: (9000,)
# File: A00375 - Shape: (9000,)
# File: A06039 - Shape: (9454,)
# File: A06316 - Shape: (10086,)
# File: A00436 - Shape: (9000,)
# File: A05580 - Shape: (18000,)
# File: A08263 - Shape: (9000,)
# File: A03467 - Shape: (4496,)
# File: A08151 - Shape: (9000,)
# File: A02140 - Shape: (5740,)
# File: A05688 - Shape: (12030,)
# File: A03682 - Shape: (9000,)
# File: A05673 - Shape: (11624,)
# File: A05920 - Shape: (17186,)
# File: A00357 - Shape: (6016,)
# File: A03121 - Shape: (9000,)
# File: A07967 - Shape: (4444,)
# File: A05885 - Shape: (9000,)
# File: A03465 - Shape: (14010,)
# File: A02855 - Shape: (9000,)
# File: A03063 - Shape: (9000,)
# File: A06956 - Shape: (9000,)
# File: A06615 - Shape: (9000,)
# File: A06674 - Shape: (9000,)
# File: A07503 - Shape: (9000,)
# File: A01871 - Shape: (9000,)
# File: A05681 - Shape: (9694,)
# File: A04543 - Shape: (9000,)
# File: A02081 - Shape: (10990,)
# File: A06499 - Shape: (9000,)
# File: A04758 - Shape: (9000,)
# File: A00098 - Shape: (9000,)
# File: A04302 - Shape: (9000,)
# File: A02417 - Shape: (9000,)
# File: A01450 - Shape: (9000,)
# File: A07798 - Shape: (9000,)
# File: A07168 - Shape: (10624,)
# File: A03658 - Shape: (4440,)
# File: A02930 - Shape: (9000,)
# File: A03415 - Shape: (9000,)
# File: A08196 - Shape: (9000,)
# File: A00969 - Shape: (9000,)
# File: A05821 - Shape: (12606,)
# File: A04790 - Shape: (9000,)
# File: A01600 - Shape: (9000,)
# File: A08418 - Shape: (18000,)
# File: A08254 - Shape: (9000,)
# File: A00313 - Shape: (18000,)
# File: A08257 - Shape: (9000,)
# File: A00925 - Shape: (9000,)
# File: A01135 - Shape: (9000,)
# File: A05635 - Shape: (9216,)
# File: A02534 - Shape: (9000,)
# File: A00279 - Shape: (9000,)
# File: A05457 - Shape: (9000,)
# File: A00266 - Shape: (9000,)
# File: A02298 - Shape: (9000,)
# File: A00032 - Shape: (8694,)
# File: A04138 - Shape: (3198,)
# File: A06503 - Shape: (10702,)
# File: A05267 - Shape: (9000,)
# File: A06062 - Shape: (17036,)
# File: A00815 - Shape: (9000,)
# File: A02899 - Shape: (9000,)
# File: A02612 - Shape: (9000,)
# File: A08215 - Shape: (18000,)
# File: A06725 - Shape: (9000,)
# File: A01271 - Shape: (9000,)
# File: A00775 - Shape: (18000,)
# File: A04006 - Shape: (9000,)
# File: A00009 - Shape: (9000,)
# File: A08002 - Shape: (9000,)
# File: A04942 - Shape: (9000,)
# File: A04067 - Shape: (9000,)
# File: A05977 - Shape: (14680,)
# File: A01698 - Shape: (9000,)
# File: A01739 - Shape: (9000,)
# File: A08369 - Shape: (18000,)
# File: A00970 - Shape: (9000,)
# File: A07418 - Shape: (9000,)
# File: A00879 - Shape: (9000,)
# File: A05397 - Shape: (9000,)
# File: A04924 - Shape: (9000,)
# File: A02033 - Shape: (9000,)
# File: A00352 - Shape: (9000,)
# File: A02080 - Shape: (9000,)
# File: A06249 - Shape: (9000,)
# File: A04497 - Shape: (9462,)
# File: A07400 - Shape: (9000,)
# File: A01776 - Shape: (9000,)
# File: A02593 - Shape: (9000,)
# File: A01542 - Shape: (18000,)
# File: A08224 - Shape: (9000,)
# File: A05573 - Shape: (9000,)
# File: A05773 - Shape: (9620,)
# File: A02736 - Shape: (9000,)
# File: A02562 - Shape: (9000,)
# File: A08337 - Shape: (3870,)
# File: A06955 - Shape: (18000,)
# File: A06028 - Shape: (12618,)
# File: A01984 - Shape: (9000,)
# File: A02569 - Shape: (9000,)
# File: A04355 - Shape: (9000,)
# File: A06066 - Shape: (9000,)
# File: A01389 - Shape: (9000,)
# File: A01989 - Shape: (9000,)
# File: A03862 - Shape: (9000,)
# File: A04033 - Shape: (9000,)
# File: A04855 - Shape: (4382,)
# File: A02096 - Shape: (9000,)
# File: A04594 - Shape: (9000,)
# File: A03769 - Shape: (9000,)
# File: A02145 - Shape: (9000,)
# File: A05146 - Shape: (9000,)
# File: A00829 - Shape: (9000,)
# File: A03191 - Shape: (9000,)
# File: A07741 - Shape: (9000,)
# File: A07108 - Shape: (9000,)
# File: A00420 - Shape: (9000,)
# File: A04949 - Shape: (9000,)
# File: A04431 - Shape: (9000,)
# File: A07128 - Shape: (9000,)
# File: A05154 - Shape: (18000,)
# File: A06852 - Shape: (9000,)
# File: A00880 - Shape: (9000,)
# File: A06753 - Shape: (9000,)
# File: A03867 - Shape: (9000,)
# File: A00066 - Shape: (9000,)
# File: A06838 - Shape: (9000,)
# File: A01704 - Shape: (9000,)
# File: A08184 - Shape: (7876,)
# File: A08485 - Shape: (3108,)
# File: A04572 - Shape: (9000,)
# File: A03973 - Shape: (9000,)
# File: A00953 - Shape: (3846,)
# File: A01003 - Shape: (9000,)
# File: A00319 - Shape: (9000,)
# File: A04647 - Shape: (9000,)
# File: A04680 - Shape: (9000,)
# File: A04432 - Shape: (9000,)
# File: A05591 - Shape: (10334,)
# File: A03238 - Shape: (9000,)
# File: A05928 - Shape: (9000,)
# File: A02422 - Shape: (18000,)
# File: A04139 - Shape: (9000,)
# File: A07657 - Shape: (9000,)
# File: A04905 - Shape: (9000,)
# File: A04923 - Shape: (9000,)
# File: A06947 - Shape: (9000,)
# File: A00727 - Shape: (9000,)
# File: A02779 - Shape: (9000,)
# File: A03648 - Shape: (9000,)
# File: A02905 - Shape: (9000,)
# File: A05405 - Shape: (9000,)
# File: A08270 - Shape: (18000,)
# File: A00046 - Shape: (9000,)
# File: A01495 - Shape: (9000,)
# File: A07649 - Shape: (9000,)
# File: A04437 - Shape: (9000,)
# File: A07065 - Shape: (9000,)
# File: A05990 - Shape: (9298,)
# File: A03770 - Shape: (9000,)
# File: A03784 - Shape: (9000,)
# File: A00372 - Shape: (5826,)
# File: A02954 - Shape: (9000,)
# File: A04800 - Shape: (9000,)
# File: A01686 - Shape: (18000,)
# File: A03054 - Shape: (5926,)
# File: A05799 - Shape: (9968,)
# File: A02850 - Shape: (9000,)
# File: A00955 - Shape: (9000,)
# File: A00411 - Shape: (6300,)
# File: A05501 - Shape: (7980,)
# File: A04120 - Shape: (9000,)
# File: A02788 - Shape: (18000,)
# File: A02813 - Shape: (9000,)
# File: A01557 - Shape: (3448,)
# File: A06459 - Shape: (9000,)
# File: A07366 - Shape: (9000,)
# File: A07113 - Shape: (11796,)
# File: A00086 - Shape: (9000,)
# File: A04269 - Shape: (9000,)
# File: A04297 - Shape: (9000,)
# File: A02673 - Shape: (9000,)
# File: A02994 - Shape: (9000,)
# File: A07655 - Shape: (9000,)
# File: A01512 - Shape: (9000,)
# File: A00053 - Shape: (9000,)
# File: A03476 - Shape: (9000,)
# File: A01732 - Shape: (9000,)
# File: A03933 - Shape: (9000,)
# File: A00865 - Shape: (9000,)
# File: A06979 - Shape: (9000,)
# File: A00281 - Shape: (9000,)
# File: A01748 - Shape: (9000,)
# File: A07199 - Shape: (9000,)
# File: A03887 - Shape: (9000,)
# File: A07640 - Shape: (9000,)
# File: A03792 - Shape: (9000,)
# File: A02823 - Shape: (9000,)
# File: A02610 - Shape: (9000,)
# File: A01511 - Shape: (5258,)
# File: A04326 - Shape: (9000,)
# File: A00481 - Shape: (9000,)
# File: A04542 - Shape: (18000,)
# File: A02621 - Shape: (9000,)
# File: A05875 - Shape: (9000,)
# File: A06736 - Shape: (9000,)
# File: A05215 - Shape: (3268,)
# File: A01104 - Shape: (9000,)
# File: A00064 - Shape: (9000,)
# File: A04019 - Shape: (18000,)
# File: A06621 - Shape: (9000,)
# File: A02536 - Shape: (9000,)
# File: A04534 - Shape: (9000,)
# File: A06616 - Shape: (4760,)
# File: A03728 - Shape: (9000,)
# File: A06597 - Shape: (9000,)
# File: A06302 - Shape: (18072,)
# File: A06225 - Shape: (9920,)
# File: A05727 - Shape: (9000,)
# File: A05049 - Shape: (9000,)
# File: A04580 - Shape: (18000,)
# File: A07112 - Shape: (9000,)
# File: A06061 - Shape: (9916,)
# File: A05472 - Shape: (9000,)
# File: A06523 - Shape: (9000,)
# File: A04319 - Shape: (9000,)
# File: A02200 - Shape: (9000,)
# File: A01712 - Shape: (9000,)
# File: A01783 - Shape: (10514,)
# File: A02757 - Shape: (18000,)
# File: A04718 - Shape: (4772,)
# File: A06880 - Shape: (9000,)
# File: A01534 - Shape: (6730,)
# File: A06643 - Shape: (9000,)
# File: A00321 - Shape: (9000,)
# File: A07227 - Shape: (9000,)
# File: A00738 - Shape: (9000,)
# File: A08524 - Shape: (9000,)
# File: A01431 - Shape: (9000,)
# File: A07121 - Shape: (9000,)
# File: A05930 - Shape: (10698,)
# File: A03288 - Shape: (9000,)
# File: A00893 - Shape: (9000,)
# File: A02600 - Shape: (9000,)
# File: A06137 - Shape: (12570,)
# File: A07595 - Shape: (2992,)
# File: A08527 - Shape: (9000,)
# File: A04087 - Shape: (9000,)
# File: A06840 - Shape: (9000,)
# File: A00998 - Shape: (9000,)
# File: A03165 - Shape: (8028,)
# File: A08522 - Shape: (9000,)
# File: A06362 - Shape: (5954,)
# File: A07697 - Shape: (7458,)
# File: A05237 - Shape: (9000,)
# File: A02504 - Shape: (11784,)
# File: A05286 - Shape: (9000,)
# File: A01428 - Shape: (9000,)
# File: A08212 - Shape: (18000,)
# File: A03347 - Shape: (9000,)
# File: A03276 - Shape: (9000,)
# File: A07514 - Shape: (9000,)
# File: A04651 - Shape: (9000,)
# File: A08349 - Shape: (9000,)
# File: A07035 - Shape: (3444,)
# File: A01019 - Shape: (9000,)
# File: A07717 - Shape: (9000,)
# File: A01610 - Shape: (9000,)
# File: A06480 - Shape: (9000,)
# File: A00546 - Shape: (9000,)
# File: A03971 - Shape: (9000,)
# File: A02457 - Shape: (5014,)
# File: A08083 - Shape: (9000,)
# File: A00654 - Shape: (9000,)
# File: A06846 - Shape: (9000,)
# File: A04765 - Shape: (9000,)
# File: A00823 - Shape: (9000,)
# File: A01256 - Shape: (9000,)
# File: A02443 - Shape: (9000,)
# File: A04922 - Shape: (9000,)
# File: A04590 - Shape: (18000,)
# File: A06539 - Shape: (9000,)
# File: A04158 - Shape: (5364,)
# File: A08382 - Shape: (7200,)
# File: A03056 - Shape: (9000,)
# File: A07381 - Shape: (3376,)
# File: A04106 - Shape: (9000,)
# File: A04007 - Shape: (18000,)
# File: A08307 - Shape: (9000,)
# File: A08031 - Shape: (18000,)
# File: A03518 - Shape: (9000,)
# File: A01923 - Shape: (9000,)
# File: A00713 - Shape: (7056,)
# File: A03964 - Shape: (9000,)
# File: A06404 - Shape: (10896,)
# File: A07231 - Shape: (9000,)
# File: A02689 - Shape: (5110,)
# File: A06632 - Shape: (9000,)
# File: A06264 - Shape: (9770,)
# File: A01335 - Shape: (9000,)
# File: A03356 - Shape: (9000,)
# File: A07163 - Shape: (9000,)
# File: A01604 - Shape: (9000,)
# File: A03813 - Shape: (9000,)
# File: A08488 - Shape: (18000,)
# File: A06063 - Shape: (9456,)
# File: A05964 - Shape: (10414,)
# File: A02950 - Shape: (9000,)
# File: A04704 - Shape: (9000,)
# File: A06068 - Shape: (10722,)
# File: A00491 - Shape: (9000,)
# File: A06159 - Shape: (9890,)
# File: A05893 - Shape: (10882,)
# File: A02509 - Shape: (9000,)
# File: A02559 - Shape: (9000,)
# File: A04053 - Shape: (18000,)
# File: A04953 - Shape: (9000,)
# File: A06285 - Shape: (9000,)
# File: A05504 - Shape: (9000,)
# File: A02908 - Shape: (9000,)
# File: A04839 - Shape: (4976,)
# File: A06297 - Shape: (10918,)
# File: A00803 - Shape: (9000,)
# File: A02050 - Shape: (9000,)
# File: A03344 - Shape: (9000,)
# File: A04101 - Shape: (9000,)
# File: A02210 - Shape: (9000,)
# File: A02763 - Shape: (9000,)
# File: A03685 - Shape: (14440,)
# File: A01768 - Shape: (18000,)
# File: A01730 - Shape: (9000,)
# File: A04817 - Shape: (9000,)
# File: A00011 - Shape: (9000,)
# File: A03962 - Shape: (9000,)
# File: A03892 - Shape: (5474,)
# File: A07653 - Shape: (9000,)
# File: A03632 - Shape: (18000,)
# File: A03925 - Shape: (9000,)
# File: A05117 - Shape: (9000,)
# File: A02141 - Shape: (9000,)
# File: A05119 - Shape: (9000,)
# File: A08020 - Shape: (6442,)
# File: A01062 - Shape: (9000,)
# File: A06486 - Shape: (9000,)
# File: A06179 - Shape: (17012,)
# File: A05294 - Shape: (9000,)
# File: A04183 - Shape: (9000,)
# File: A02861 - Shape: (9000,)
# File: A04375 - Shape: (9000,)
# File: A00358 - Shape: (18000,)
# File: A01865 - Shape: (9000,)
# File: A03255 - Shape: (9000,)
# File: A05872 - Shape: (9650,)
# File: A04161 - Shape: (9000,)
# File: A01945 - Shape: (9000,)
# File: A02939 - Shape: (9000,)
# File: A04601 - Shape: (9000,)
# File: A07535 - Shape: (8506,)
# File: A06939 - Shape: (18000,)
# File: A00328 - Shape: (9000,)
# File: A01726 - Shape: (9000,)
# File: A05607 - Shape: (11062,)
# File: A00618 - Shape: (7682,)
# File: A05410 - Shape: (9000,)
# File: A07868 - Shape: (9000,)
# File: A03918 - Shape: (18000,)
# File: A05646 - Shape: (9000,)
# File: A04632 - Shape: (9000,)
# File: A06410 - Shape: (18000,)
# File: A06690 - Shape: (15386,)
# File: A02901 - Shape: (9000,)
# File: A05555 - Shape: (5046,)
# File: A00748 - Shape: (9000,)
# File: A01423 - Shape: (9000,)
# File: A05664 - Shape: (9620,)
# File: A05629 - Shape: (9000,)
# File: A04253 - Shape: (9000,)
# File: A05987 - Shape: (9000,)
# File: A06954 - Shape: (9000,)
# File: A06927 - Shape: (9000,)
# File: A00144 - Shape: (9000,)
# File: A02137 - Shape: (9000,)
# File: A03036 - Shape: (9000,)
# File: A02078 - Shape: (9000,)
# File: A04016 - Shape: (9000,)
# File: A03627 - Shape: (9000,)
# File: A06577 - Shape: (9000,)
# File: A01490 - Shape: (9000,)
# File: A03471 - Shape: (9000,)
# File: A01179 - Shape: (9000,)
# File: A08420 - Shape: (9000,)
# File: A00332 - Shape: (9000,)
# File: A03296 - Shape: (9000,)
# File: A08018 - Shape: (6372,)
# File: A01384 - Shape: (18000,)
# File: A00938 - Shape: (9000,)
# File: A07053 - Shape: (18000,)
# File: A06722 - Shape: (9000,)
# File: A07972 - Shape: (9000,)
# File: A01321 - Shape: (9000,)
# File: A04991 - Shape: (9000,)
# File: A06902 - Shape: (9000,)
# File: A02767 - Shape: (9000,)
# File: A04786 - Shape: (9000,)
# File: A08192 - Shape: (17851,)
# File: A03602 - Shape: (9162,)
# File: A04171 - Shape: (9000,)
# File: A05137 - Shape: (9000,)
# File: A02188 - Shape: (9000,)
# File: A02155 - Shape: (9000,)
# File: A07917 - Shape: (9000,)
# File: A05404 - Shape: (9000,)
# File: A06743 - Shape: (9000,)
# File: A04383 - Shape: (18000,)
# File: A04987 - Shape: (10328,)
# File: A02313 - Shape: (9000,)
# File: A05158 - Shape: (9000,)
# File: A06163 - Shape: (10964,)
# File: A07230 - Shape: (9000,)
# File: A07346 - Shape: (9000,)
# File: A02873 - Shape: (9000,)
# File: A05140 - Shape: (9000,)
# File: A04552 - Shape: (9000,)
# File: A02393 - Shape: (9000,)
# File: A03236 - Shape: (9000,)
# File: A03686 - Shape: (9000,)
# File: A04806 - Shape: (9000,)
# File: A00193 - Shape: (9000,)
# File: A05612 - Shape: (11936,)
# File: A01674 - Shape: (9000,)
# File: A03380 - Shape: (9000,)
# File: A04485 - Shape: (9000,)
# File: A03561 - Shape: (9000,)
# File: A02711 - Shape: (9000,)
# File: A03135 - Shape: (9000,)
# File: A05182 - Shape: (9000,)
# File: A01118 - Shape: (9000,)
# File: A05855 - Shape: (11902,)
# File: A01821 - Shape: (9000,)
# File: A07024 - Shape: (13160,)
# File: A02000 - Shape: (9000,)
# File: A08465 - Shape: (9000,)
# File: A07459 - Shape: (9000,)
# File: A00221 - Shape: (3306,)
# File: A05259 - Shape: (9000,)
# File: A07519 - Shape: (9000,)
# File: A04637 - Shape: (18000,)
# File: A06678 - Shape: (9000,)
# File: A07357 - Shape: (9000,)
# File: A07045 - Shape: (9000,)
# File: A06382 - Shape: (9000,)
# File: A05721 - Shape: (9000,)
# File: A06657 - Shape: (9000,)
# File: A06150 - Shape: (10644,)
# File: A03018 - Shape: (9424,)
# File: A06431 - Shape: (9000,)
# File: A00455 - Shape: (18000,)
# File: A00378 - Shape: (9000,)
# File: A06896 - Shape: (9000,)
# File: A06812 - Shape: (9000,)
# File: A01211 - Shape: (9000,)
# File: A05625 - Shape: (9000,)
# File: A01024 - Shape: (18000,)
# File: A01046 - Shape: (9000,)
# File: A05744 - Shape: (9522,)
# File: A00691 - Shape: (9000,)
# File: A06681 - Shape: (9000,)
# File: A07604 - Shape: (9000,)
# File: A07206 - Shape: (9000,)
# File: A06412 - Shape: (18000,)
# File: A06957 - Shape: (9000,)
# File: A03237 - Shape: (9000,)
# File: A03893 - Shape: (9000,)
# File: A07453 - Shape: (9000,)
# File: A03984 - Shape: (18000,)
# File: A01523 - Shape: (9000,)
# File: A04841 - Shape: (9000,)
# File: A07146 - Shape: (14246,)
# File: A05762 - Shape: (9450,)
# File: A01940 - Shape: (9000,)
# File: A06162 - Shape: (9000,)
# File: A02752 - Shape: (9000,)
# File: A02476 - Shape: (9000,)
# File: A02310 - Shape: (9000,)
# File: A02611 - Shape: (9000,)
# File: A08218 - Shape: (9000,)
# File: A08255 - Shape: (9000,)
# File: A06711 - Shape: (9000,)
# File: A03567 - Shape: (9000,)
# File: A00240 - Shape: (9000,)
# File: A06525 - Shape: (9000,)
# File: A01002 - Shape: (3022,)
# File: A02998 - Shape: (9000,)
# File: A03024 - Shape: (9000,)
# File: A00026 - Shape: (9000,)
# File: A02147 - Shape: (9000,)
# File: A04289 - Shape: (9000,)
# File: A03129 - Shape: (9000,)
# File: A02886 - Shape: (17906,)
# File: A01509 - Shape: (9000,)
# File: A02216 - Shape: (9000,)
# File: A02656 - Shape: (9000,)
# File: A03023 - Shape: (9000,)
# File: A01713 - Shape: (7628,)
# File: A00002 - Shape: (9000,)
# File: A05165 - Shape: (9000,)
# File: A06716 - Shape: (9000,)
# File: A06975 - Shape: (7150,)
# File: A07838 - Shape: (9000,)
# File: A03636 - Shape: (9000,)
# File: A02058 - Shape: (9000,)
# File: A03102 - Shape: (18000,)
# File: A04080 - Shape: (3992,)
# File: A07191 - Shape: (9000,)
# File: A01258 - Shape: (3842,)
# File: A06449 - Shape: (9000,)
# File: A07840 - Shape: (18188,)
# File: A02209 - Shape: (9000,)
# File: A06542 - Shape: (9000,)
# File: A02034 - Shape: (9000,)
# File: A04947 - Shape: (9000,)
# File: A07398 - Shape: (9000,)
# File: A03299 - Shape: (9000,)
# File: A06718 - Shape: (9000,)
# File: A05572 - Shape: (9000,)
# File: A07107 - Shape: (9000,)
# File: A07979 - Shape: (9000,)
# File: A03491 - Shape: (9000,)
# File: A00899 - Shape: (18000,)
# File: A08079 - Shape: (4480,)
# File: A00982 - Shape: (9000,)
# File: A06177 - Shape: (15000,)
# File: A04411 - Shape: (9000,)
# File: A06822 - Shape: (9000,)
# File: A01142 - Shape: (9000,)
# File: A05815 - Shape: (18066,)
# File: A07488 - Shape: (4982,)
# File: A03037 - Shape: (9000,)
# File: A06670 - Shape: (9000,)
# File: A07536 - Shape: (9000,)
# File: A04554 - Shape: (5448,)
# File: A08457 - Shape: (9000,)
# File: A06842 - Shape: (9000,)
# File: A08129 - Shape: (9000,)
# File: A01794 - Shape: (5692,)
# File: A00217 - Shape: (9000,)
# File: A06081 - Shape: (9626,)
# File: A02037 - Shape: (9000,)
# File: A01355 - Shape: (9000,)
# File: A07608 - Shape: (9000,)
# File: A04938 - Shape: (15008,)
# File: A04446 - Shape: (9000,)
# File: A00966 - Shape: (9000,)
# File: A03003 - Shape: (5982,)
# File: A03560 - Shape: (9000,)
# File: A04871 - Shape: (9000,)
# File: A03997 - Shape: (3590,)
# File: A05164 - Shape: (5512,)
# File: A07010 - Shape: (18000,)
# File: A04204 - Shape: (3600,)
# File: A05210 - Shape: (9000,)
# File: A06699 - Shape: (9000,)
# File: A04492 - Shape: (9000,)
# File: A05958 - Shape: (9000,)
# File: A01976 - Shape: (9000,)
# File: A03025 - Shape: (9000,)
# File: A05321 - Shape: (9000,)
# File: A01595 - Shape: (9000,)
# File: A02532 - Shape: (9000,)
# File: A04818 - Shape: (6546,)
# File: A08271 - Shape: (9000,)
# File: A07598 - Shape: (9000,)
# File: A04349 - Shape: (9000,)
# File: A00808 - Shape: (9000,)
# File: A04224 - Shape: (9000,)
# File: A03273 - Shape: (9000,)
# File: A01874 - Shape: (9000,)
# File: A00961 - Shape: (9000,)
# File: A01684 - Shape: (9000,)
# File: A06181 - Shape: (9000,)
# File: A07188 - Shape: (17040,)
# File: A06109 - Shape: (11220,)
# File: A03786 - Shape: (9000,)
# File: A00765 - Shape: (9000,)
# File: A04312 - Shape: (9000,)
# File: A01026 - Shape: (18000,)
# File: A07262 - Shape: (9000,)
# File: A05524 - Shape: (9000,)
# File: A08366 - Shape: (9000,)
# File: A05057 - Shape: (10800,)
# File: A06698 - Shape: (9000,)
# File: A03260 - Shape: (9000,)
# File: A01313 - Shape: (9000,)
# File: A07710 - Shape: (9000,)
# File: A04124 - Shape: (9000,)
# File: A00571 - Shape: (18000,)
# File: A08513 - Shape: (12470,)
# File: A07300 - Shape: (5960,)
# File: A02770 - Shape: (9000,)
# File: A06251 - Shape: (9000,)
# File: A02563 - Shape: (9000,)
# File: A05023 - Shape: (9000,)
# File: A03711 - Shape: (9000,)
# File: A04903 - Shape: (9000,)
# File: A02442 - Shape: (9000,)
# File: A07676 - Shape: (6432,)
# File: A02561 - Shape: (9000,)
# File: A05949 - Shape: (10016,)
# File: A06074 - Shape: (9000,)
# File: A01934 - Shape: (9474,)
# File: A01157 - Shape: (9000,)
# File: A00873 - Shape: (9000,)
# File: A03584 - Shape: (6012,)
# File: A01998 - Shape: (9000,)
# File: A04220 - Shape: (5998,)
# File: A02385 - Shape: (9000,)
# File: A00576 - Shape: (9000,)
# File: A01642 - Shape: (9000,)
# File: A07873 - Shape: (9000,)
# File: A04061 - Shape: (9000,)
# File: A03899 - Shape: (9000,)
# File: A02582 - Shape: (9000,)
# File: A08496 - Shape: (9000,)
# File: A00912 - Shape: (9000,)
# File: A03441 - Shape: (9000,)
# File: A06146 - Shape: (9000,)
# File: A05651 - Shape: (10338,)
# File: A03576 - Shape: (9000,)
# File: A01662 - Shape: (9000,)
# File: A08123 - Shape: (9000,)
# File: A06037 - Shape: (9000,)
# File: A01959 - Shape: (9000,)
# File: A00939 - Shape: (9000,)
# File: A05052 - Shape: (11110,)
# File: A04321 - Shape: (9000,)
# File: A05604 - Shape: (9000,)
# File: A07336 - Shape: (7916,)
# File: A01936 - Shape: (9000,)
# File: A03635 - Shape: (18000,)
# File: A03107 - Shape: (9000,)
# File: A01569 - Shape: (9000,)
# File: A02624 - Shape: (9000,)
# File: A02782 - Shape: (9000,)
# File: A07282 - Shape: (9000,)
# File: A06912 - Shape: (9000,)
# File: A05999 - Shape: (9278,)
# File: A05794 - Shape: (9442,)
# File: A07392 - Shape: (4034,)
# File: A04996 - Shape: (9000,)
# File: A07700 - Shape: (9000,)
# File: A04599 - Shape: (9000,)
# File: A02343 - Shape: (9000,)
# File: A02001 - Shape: (4290,)
# File: A07111 - Shape: (9000,)
# File: A06398 - Shape: (9000,)
# File: A04681 - Shape: (9000,)
# File: A01485 - Shape: (4864,)
# File: A08455 - Shape: (9000,)
# File: A06168 - Shape: (9000,)
# File: A02805 - Shape: (9000,)
# File: A00365 - Shape: (9000,)
# File: A04162 - Shape: (9000,)
# File: A08000 - Shape: (9000,)
# File: A00269 - Shape: (9000,)
# File: A05272 - Shape: (9000,)
# File: A04445 - Shape: (9000,)
# File: A04956 - Shape: (18000,)
# File: A00980 - Shape: (3464,)
# File: A01039 - Shape: (9000,)
# File: A05209 - Shape: (9000,)
# File: A04595 - Shape: (18000,)
# File: A01671 - Shape: (9000,)
# File: A02261 - Shape: (9000,)
# File: A02404 - Shape: (9000,)
# File: A00127 - Shape: (9000,)
# File: A05473 - Shape: (9000,)
# File: A08214 - Shape: (9000,)
# File: A05786 - Shape: (9000,)
# File: A01058 - Shape: (9000,)
# File: A06905 - Shape: (9000,)
# File: A08053 - Shape: (18000,)
# File: A07585 - Shape: (9000,)
# File: A01493 - Shape: (7878,)
# File: A05998 - Shape: (9000,)
# File: A04850 - Shape: (9000,)
# File: A04660 - Shape: (9000,)
# File: A08227 - Shape: (9000,)
# File: A04395 - Shape: (7302,)
# File: A05094 - Shape: (9000,)
# File: A06606 - Shape: (9000,)
# File: A06555 - Shape: (9000,)
# File: A05752 - Shape: (18102,)
# File: A00299 - Shape: (9000,)
# File: A06936 - Shape: (9000,)
# File: A07553 - Shape: (9000,)
# File: A03419 - Shape: (17922,)
# File: A04197 - Shape: (9000,)
# File: A06409 - Shape: (3532,)
# File: A05863 - Shape: (17390,)
# File: A08467 - Shape: (3472,)
# File: A02871 - Shape: (9000,)
# File: A07342 - Shape: (9000,)
# File: A00475 - Shape: (9000,)
# File: A05188 - Shape: (9000,)
# ...
# File: A07594 - Shape: (9000,)
# File: A05441 - Shape: (9000,)
# File: A04208 - Shape: (9000,)
# File: A00346 - Shape: (9000,)
# File: A04142 - Shape: (9000,)
# File: A04766 - Shape: (9000,)
# File: A08082 - Shape: (4812,)
# File: A07712 - Shape: (9000,)
# File: A01222 - Shape: (9000,)
# File: A04908 - Shape: (9000,)
# File: A07888 - Shape: (9000,)
# File: A08152 - Shape: (9000,)
# File: A07886 - Shape: (18000,)
# File: A00580 - Shape: (9000,)
# File: A06825 - Shape: (9000,)
# File: A01658 - Shape: (9000,)
# File: A01537 - Shape: (9000,)
# File: A05347 - Shape: (9000,)
# File: A00964 - Shape: (9000,)
# File: A02987 - Shape: (9000,)
# File: A00804 - Shape: (9000,)
# File: A05161 - Shape: (9000,)
# File: A01597 - Shape: (9798,)
# File: A04932 - Shape: (4360,)
# File: A07333 - Shape: (18000,)
# File: A02677 - Shape: (9000,)
# File: A05223 - Shape: (17366,)
# File: A02186 - Shape: (18000,)
# File: A01097 - Shape: (9000,)
# File: A03185 - Shape: (9000,)
# File: A01637 - Shape: (9000,)
# File: A03975 - Shape: (9000,)
# File: A03876 - Shape: (9000,)
# File: A00870 - Shape: (9000,)
# File: A05955 - Shape: (10498,)
# File: A03882 - Shape: (9000,)
# File: A06618 - Shape: (9000,)
# File: A04884 - Shape: (6984,)
# File: A02651 - Shape: (9000,)
# File: A05426 - Shape: (9000,)
# File: A07384 - Shape: (9000,)
# File: A02021 - Shape: (18000,)
# File: A07416 - Shape: (9000,)
# File: A06267 - Shape: (9000,)
# File: A01392 - Shape: (9000,)
# File: A05844 - Shape: (18238,)
# File: A03032 - Shape: (9000,)
# File: A08327 - Shape: (9000,)
# File: A01415 - Shape: (9000,)
# File: A07309 - Shape: (9000,)
# File: A05427 - Shape: (9000,)
# File: A02793 - Shape: (9000,)
# File: A06083 - Shape: (12436,)
# File: A01990 - Shape: (8670,)
# File: A00487 - Shape: (18000,)
# File: A07175 - Shape: (9000,)
# File: A05742 - Shape: (9882,)
# File: A04709 - Shape: (9000,)
# File: A01617 - Shape: (12838,)
# File: A01290 - Shape: (9000,)
# File: A05222 - Shape: (9000,)
# File: A08074 - Shape: (8180,)
# File: A04608 - Shape: (18000,)
# File: A06998 - Shape: (9000,)
# File: A07506 - Shape: (9000,)
# File: A02324 - Shape: (9000,)
# File: A02244 - Shape: (9000,)
# File: A05402 - Shape: (9000,)
# File: A05699 - Shape: (14282,)
# File: A04613 - Shape: (9000,)
# File: A06962 - Shape: (9000,)
# File: A06277 - Shape: (9000,)
# File: A08225 - Shape: (3338,)
# File: A04037 - Shape: (6310,)
# File: A03593 - Shape: (9000,)
# File: A00124 - Shape: (9000,)
# File: A04547 - Shape: (9000,)
# File: A00429 - Shape: (7064,)
# File: A06085 - Shape: (9138,)
# File: A03179 - Shape: (18000,)
# File: A08168 - Shape: (9000,)
# File: A07092 - Shape: (9000,)
# File: A03859 - Shape: (9000,)
# File: A04616 - Shape: (9000,)
# File: A04508 - Shape: (6028,)
# File: A07293 - Shape: (3222,)
# File: A04502 - Shape: (9000,)
# File: A03961 - Shape: (9000,)
# File: A05322 - Shape: (9000,)
# File: A07324 - Shape: (9000,)
# File: A03795 - Shape: (9000,)
# File: A01932 - Shape: (3264,)
# File: A01506 - Shape: (9294,)
# File: A04467 - Shape: (18000,)
# File: A08514 - Shape: (3364,)
# File: A05852 - Shape: (9292,)
# File: A04459 - Shape: (9000,)
# File: A01752 - Shape: (9000,)
# File: A03325 - Shape: (9000,)
# File: A07399 - Shape: (9000,)
# File: A04782 - Shape: (9000,)
# File: A00783 - Shape: (9000,)
# File: A05854 - Shape: (9000,)
# File: A01659 - Shape: (18000,)
# File: A00062 - Shape: (9000,)
# File: A03235 - Shape: (9000,)
# File: A00463 - Shape: (18000,)
# File: A05918 - Shape: (17250,)
# File: A07788 - Shape: (9000,)
# File: A05251 - Shape: (9000,)
# File: A05645 - Shape: (9480,)
# File: A05770 - Shape: (11446,)
# File: A05025 - Shape: (18000,)
# File: A06665 - Shape: (9000,)
# File: A06018 - Shape: (9774,)
# File: A00551 - Shape: (9000,)
# File: A03265 - Shape: (18000,)
# File: A06723 - Shape: (9000,)
# File: A08422 - Shape: (3252,)
# File: A01964 - Shape: (4350,)
# File: A07502 - Shape: (9000,)
# File: A08280 - Shape: (9000,)
# File: A02652 - Shape: (9000,)
# File: A06731 - Shape: (9000,)
# File: A02167 - Shape: (4522,)
# File: A00566 - Shape: (18000,)
# File: A07428 - Shape: (9000,)
# File: A07753 - Shape: (9000,)
# File: A03313 - Shape: (9000,)
# File: A00432 - Shape: (9000,)
# File: A08325 - Shape: (18000,)
# File: A06752 - Shape: (6324,)
# File: A01884 - Shape: (9000,)
# File: A00676 - Shape: (18000,)
# File: A02497 - Shape: (9000,)
# File: A02591 - Shape: (9000,)
# File: A07244 - Shape: (18000,)
# File: A00891 - Shape: (9000,)
# File: A07043 - Shape: (9000,)
# File: A06667 - Shape: (4298,)
# File: A05868 - Shape: (9930,)
# File: A07284 - Shape: (9000,)
# File: A08460 - Shape: (12860,)
# File: A02219 - Shape: (9000,)
# File: A05565 - Shape: (9000,)
# File: A02464 - Shape: (9000,)
# File: A00672 - Shape: (9000,)
# File: A06147 - Shape: (9000,)
# File: A05131 - Shape: (6226,)
# File: A03608 - Shape: (9000,)
# File: A01309 - Shape: (9000,)
# File: A04340 - Shape: (9000,)
# File: A00934 - Shape: (9000,)
# File: A00490 - Shape: (9000,)
# File: A06780 - Shape: (9000,)
# File: A07569 - Shape: (9000,)
# File: A03468 - Shape: (18000,)
# File: A05903 - Shape: (9984,)
# File: A07311 - Shape: (9000,)
# File: A00845 - Shape: (9000,)
# File: A03163 - Shape: (9000,)
# File: A02640 - Shape: (9000,)
# File: A01017 - Shape: (7856,)
# File: A07945 - Shape: (9000,)
# File: A04992 - Shape: (6526,)
# File: A06124 - Shape: (9000,)
# File: A07751 - Shape: (9000,)
# File: A00454 - Shape: (18000,)
# File: A00512 - Shape: (9000,)
# File: A03123 - Shape: (9000,)
# File: A03099 - Shape: (9000,)
# File: A08138 - Shape: (3634,)
# File: A06637 - Shape: (9000,)
# File: A02174 - Shape: (12014,)
# File: A01069 - Shape: (9000,)
# File: A00888 - Shape: (9000,)
# File: A08466 - Shape: (9000,)
# File: A00772 - Shape: (9000,)
# File: A07057 - Shape: (18000,)
# File: A05317 - Shape: (9000,)
# File: A06065 - Shape: (10504,)
# File: A02221 - Shape: (9000,)
# File: A03957 - Shape: (9000,)
# File: A00407 - Shape: (9000,)
# File: A03197 - Shape: (9000,)
# File: A02909 - Shape: (7136,)
# File: A00309 - Shape: (9000,)
# File: A02608 - Shape: (18000,)
# File: A05338 - Shape: (9000,)
# File: A08084 - Shape: (9000,)
# File: A06730 - Shape: (9000,)
# File: A07824 - Shape: (9000,)
# File: A01425 - Shape: (9000,)
# File: A00743 - Shape: (9000,)
# File: A03803 - Shape: (9000,)
# File: A05817 - Shape: (9000,)
# File: A06393 - Shape: (9000,)
# File: A07682 - Shape: (9000,)
# File: A04848 - Shape: (9000,)
# File: A03045 - Shape: (14280,)
# File: A06779 - Shape: (9000,)
# File: A06796 - Shape: (8504,)
# File: A01255 - Shape: (9000,)
# File: A03194 - Shape: (3572,)
# File: A07240 - Shape: (18000,)
# File: A04937 - Shape: (5076,)
# File: A03907 - Shape: (9000,)
# File: A05682 - Shape: (9450,)
# File: A02653 - Shape: (11592,)
# File: A01034 - Shape: (9000,)
# File: A08111 - Shape: (9000,)
# File: A06864 - Shape: (4977,)
# File: A02162 - Shape: (9000,)
# File: A05579 - Shape: (9000,)
# File: A02580 - Shape: (9000,)
# File: A06166 - Shape: (9000,)
# File: A08441 - Shape: (9000,)
# File: A05940 - Shape: (9972,)
# File: A00798 - Shape: (6114,)
# File: A00941 - Shape: (9000,)
# File: A06932 - Shape: (9000,)
# File: A05363 - Shape: (9000,)
# File: A05370 - Shape: (9000,)
# File: A03241 - Shape: (18000,)
# File: A02766 - Shape: (13180,)
# File: A04084 - Shape: (9000,)
# File: A08098 - Shape: (9000,)
# File: A00726 - Shape: (9000,)
# File: A00191 - Shape: (9000,)
# File: A06819 - Shape: (18000,)
# File: A08472 - Shape: (9000,)
# File: A02201 - Shape: (9000,)
# File: A02811 - Shape: (9000,)
# File: A02728 - Shape: (9000,)
# File: A06787 - Shape: (9000,)
# File: A00442 - Shape: (9000,)
# File: A02172 - Shape: (9000,)
# File: A06843 - Shape: (9000,)
# File: A00643 - Shape: (18000,)
# File: A05676 - Shape: (10896,)
# File: A07235 - Shape: (9000,)
# File: A00922 - Shape: (18000,)
# File: A04489 - Shape: (5696,)
# File: A02306 - Shape: (9000,)
# File: A06185 - Shape: (9650,)
# File: A01803 - Shape: (9000,)
# File: A03508 - Shape: (9000,)
# File: A00677 - Shape: (9000,)
# File: A02581 - Shape: (9000,)
# File: A03680 - Shape: (9000,)
# File: A03509 - Shape: (9000,)
# File: A08315 - Shape: (9000,)
# File: A04778 - Shape: (18000,)
# File: A07359 - Shape: (9000,)
# File: A00233 - Shape: (9000,)
# File: A06255 - Shape: (10130,)
# File: A07257 - Shape: (9000,)
# File: A06771 - Shape: (9000,)
# File: A02941 - Shape: (9000,)
# File: A03203 - Shape: (5244,)
# File: A03921 - Shape: (9000,)
# File: A04861 - Shape: (9000,)
# File: A07950 - Shape: (9000,)
# File: A04305 - Shape: (9000,)
# File: A00045 - Shape: (9000,)
# File: A06645 - Shape: (9000,)
# File: A00644 - Shape: (9000,)
# File: A07984 - Shape: (11872,)
# File: A00084 - Shape: (9000,)
# File: A02744 - Shape: (9000,)
# File: A03377 - Shape: (9000,)
# File: A07882 - Shape: (18000,)
# File: A05239 - Shape: (18000,)
# File: A02554 - Shape: (9000,)
# File: A00800 - Shape: (9000,)
# File: A06876 - Shape: (9000,)
# File: A06423 - Shape: (9000,)
# File: A07318 - Shape: (9000,)
# File: A03906 - Shape: (18000,)
# File: A04910 - Shape: (6946,)
# File: A01238 - Shape: (9000,)
# File: A01857 - Shape: (9000,)
# File: A01372 - Shape: (9000,)
# File: A01283 - Shape: (9000,)
# File: A01721 - Shape: (9000,)
# File: A06370 - Shape: (9000,)
# File: A06563 - Shape: (9000,)
# File: A00648 - Shape: (3494,)
# File: A03548 - Shape: (9000,)
# File: A02458 - Shape: (9000,)
# File: A00639 - Shape: (9000,)
# File: A06402 - Shape: (4722,)
# File: A08107 - Shape: (18000,)
# File: A06049 - Shape: (9396,)
# File: A06100 - Shape: (9000,)
# File: A00655 - Shape: (7934,)
# File: A06351 - Shape: (9000,)
# File: A06328 - Shape: (9000,)
# File: A04246 - Shape: (9000,)
# File: A06732 - Shape: (4492,)
# File: A00280 - Shape: (9000,)
# File: A00295 - Shape: (9000,)
# File: A04011 - Shape: (9000,)
# File: A05369 - Shape: (9000,)
# File: A06127 - Shape: (9000,)
# File: A02853 - Shape: (9000,)
# File: A03787 - Shape: (3748,)
# File: A05162 - Shape: (7328,)
# File: A00271 - Shape: (9000,)
# File: A04906 - Shape: (9000,)
# File: A05559 - Shape: (9000,)
# File: A03912 - Shape: (9000,)
# File: A08157 - Shape: (9000,)
# File: A06849 - Shape: (4666,)
# File: A05303 - Shape: (9000,)
# File: A07905 - Shape: (9000,)
# File: A04385 - Shape: (18000,)
# File: A05889 - Shape: (12970,)
# File: A07319 - Shape: (9000,)
# File: A01926 - Shape: (7522,)
# File: A06321 - Shape: (9470,)
# File: A07169 - Shape: (9000,)
# File: A02029 - Shape: (9000,)
# File: A03841 - Shape: (9000,)
# File: A06628 - Shape: (9000,)
# File: A03401 - Shape: (3324,)
# File: A03369 - Shape: (9000,)
# File: A06930 - Shape: (9000,)
# File: A05088 - Shape: (9000,)
# File: A03874 - Shape: (9000,)
# File: A03031 - Shape: (9000,)
# File: A04390 - Shape: (9000,)
# File: A00918 - Shape: (9000,)
# File: A00814 - Shape: (9000,)
# File: A08446 - Shape: (9000,)
# File: A07248 - Shape: (9000,)
# File: A05738 - Shape: (13398,)
# File: A04131 - Shape: (9000,)
# File: A07861 - Shape: (9000,)
# File: A02727 - Shape: (9000,)
# File: A08350 - Shape: (9000,)
# File: A06104 - Shape: (16602,)
# File: A06349 - Shape: (9000,)
# File: A07212 - Shape: (3906,)
# File: A01528 - Shape: (18000,)
# File: A00573 - Shape: (17390,)
# File: A08305 - Shape: (18000,)
# File: A02450 - Shape: (9000,)
# File: A02483 - Shape: (6792,)
# File: A01742 - Shape: (9000,)
# File: A07241 - Shape: (5266,)
# File: A04978 - Shape: (9000,)
# File: A01507 - Shape: (9000,)
# File: A03836 - Shape: (9000,)
# File: A06915 - Shape: (9000,)
# File: A08354 - Shape: (7554,)
# File: A05847 - Shape: (14814,)
# File: A08236 - Shape: (5246,)
# File: A04957 - Shape: (9000,)
# File: A04419 - Shape: (18000,)
# File: A03656 - Shape: (6594,)
# File: A03028 - Shape: (17908,)
# File: A04077 - Shape: (9000,)
# File: A06744 - Shape: (9000,)
# File: A04826 - Shape: (9000,)
# File: A01615 - Shape: (15292,)
# File: A02684 - Shape: (7936,)
# File: A05991 - Shape: (16890,)
# File: A00597 - Shape: (3536,)
# File: A06394 - Shape: (9000,)
# File: A03213 - Shape: (9000,)
# File: A06433 - Shape: (5100,)
# File: A05253 - Shape: (9000,)
# File: A07326 - Shape: (9000,)
# File: A01416 - Shape: (9000,)
# File: A01210 - Shape: (18000,)
# File: A02289 - Shape: (9000,)
# File: A06471 - Shape: (9000,)
# File: A02290 - Shape: (9000,)
# File: A00506 - Shape: (9000,)
# File: A04035 - Shape: (18000,)
# File: A03958 - Shape: (9000,)
# File: A03264 - Shape: (9000,)
# File: A00417 - Shape: (9000,)
# File: A02045 - Shape: (9000,)
# File: A08294 - Shape: (9000,)
# File: A04813 - Shape: (9000,)
# File: A06143 - Shape: (9664,)
# File: A02606 - Shape: (9000,)
# File: A05461 - Shape: (9000,)
# File: A07994 - Shape: (9000,)
# File: A01791 - Shape: (9000,)
# File: A07705 - Shape: (9000,)
# File: A01430 - Shape: (10444,)
# File: A00216 - Shape: (9000,)
# File: A00926 - Shape: (9000,)
# File: A01166 - Shape: (5729,)
# File: A05361 - Shape: (9000,)
# File: A03536 - Shape: (9000,)
# File: A06859 - Shape: (9000,)
# File: A07661 - Shape: (9000,)
# File: A02015 - Shape: (9000,)
# File: A01155 - Shape: (9000,)
# File: A03995 - Shape: (9000,)
# File: A04190 - Shape: (9000,)
# File: A04116 - Shape: (9000,)
# File: A06207 - Shape: (12234,)
# File: A05293 - Shape: (9000,)
# File: A05111 - Shape: (18000,)
# File: A04015 - Shape: (9000,)
# File: A06491 - Shape: (9000,)
# File: A00464 - Shape: (3972,)
# File: A01296 - Shape: (9000,)
# File: A03364 - Shape: (9000,)
# File: A03897 - Shape: (9000,)
# File: A05856 - Shape: (10136,)
# File: A05877 - Shape: (9000,)
# File: A04604 - Shape: (9000,)
# File: A02604 - Shape: (9000,)
# File: A01302 - Shape: (18000,)
# File: A02542 - Shape: (9000,)
# File: A07843 - Shape: (9000,)
# File: A07147 - Shape: (9000,)
# File: A08174 - Shape: (9000,)
# File: A02131 - Shape: (9000,)
# File: A03703 - Shape: (9000,)
# File: A08274 - Shape: (6320,)
# File: A04879 - Shape: (4152,)
# File: A01868 - Shape: (9000,)
# File: A08506 - Shape: (9000,)
# File: A03743 - Shape: (9000,)
# File: A00609 - Shape: (4702,)
# File: A00517 - Shape: (18000,)
# File: A02972 - Shape: (9000,)
# File: A01895 - Shape: (9000,)
# File: A00960 - Shape: (9000,)
# File: A01900 - Shape: (9000,)
# File: A05106 - Shape: (18000,)
# File: A06817 - Shape: (9000,)
# File: A07826 - Shape: (9000,)
# File: A06687 - Shape: (9000,)
# File: A00097 - Shape: (9000,)
# File: A00516 - Shape: (9000,)
# File: A01879 - Shape: (6894,)
# File: A07748 - Shape: (9000,)
# File: A07852 - Shape: (9000,)
# File: A02515 - Shape: (9000,)
# File: A02597 - Shape: (7822,)
# File: A07450 - Shape: (18000,)
# File: A02691 - Shape: (9000,)
# File: A03716 - Shape: (9000,)
# File: A08486 - Shape: (5522,)
# File: A00403 - Shape: (9000,)
# File: A01629 - Shape: (5502,)
# File: A01866 - Shape: (9000,)
# File: A08360 - Shape: (9000,)
# File: A04675 - Shape: (4174,)
# File: A04664 - Shape: (9000,)
# File: A06233 - Shape: (9000,)
# File: A01421 - Shape: (9000,)
# File: A00806 - Shape: (9000,)
# File: A05827 - Shape: (9826,)
# File: A01176 - Shape: (9000,)
# File: A06763 - Shape: (9000,)
# File: A04378 - Shape: (9000,)
# File: A03563 - Shape: (9000,)
# File: A03151 - Shape: (10486,)
# File: A07856 - Shape: (9000,)
# File: A02674 - Shape: (9000,)
# File: A06999 - Shape: (9000,)
# File: A08243 - Shape: (9000,)
# File: A06174 - Shape: (9634,)
# File: A05141 - Shape: (9000,)
# File: A00858 - Shape: (9000,)
# File: A04182 - Shape: (9000,)
# File: A01202 - Shape: (9000,)
# File: A00838 - Shape: (9000,)
# File: A05723 - Shape: (9000,)
# File: A05959 - Shape: (9000,)
# File: A05650 - Shape: (10146,)
# File: A06726 - Shape: (6614,)
# File: A01206 - Shape: (9000,)
# File: A06379 - Shape: (9000,)
# File: A00465 - Shape: (9000,)
# File: A00469 - Shape: (9000,)
# File: A07258 - Shape: (9000,)
# File: A05478 - Shape: (18000,)
# File: A07611 - Shape: (9000,)
# File: A00531 - Shape: (9000,)
# File: A05022 - Shape: (9000,)
# File: A07766 - Shape: (9000,)
# File: A07499 - Shape: (2928,)
# File: A07047 - Shape: (9000,)
# File: A04907 - Shape: (9000,)
# File: A02203 - Shape: (9000,)
# File: A01524 - Shape: (9000,)
# File: A04823 - Shape: (9000,)
# File: A06923 - Shape: (9000,)
# File: A08424 - Shape: (9000,)
# File: A06497 - Shape: (9000,)
# File: A02876 - Shape: (18000,)
# File: A03722 - Shape: (18000,)
# File: A07555 - Shape: (9000,)
# File: A05716 - Shape: (9000,)
# File: A03524 - Shape: (9000,)
# File: A04760 - Shape: (9000,)
# File: A04221 - Shape: (9000,)
# File: A01656 - Shape: (8430,)
# File: A01141 - Shape: (9000,)
# File: A02553 - Shape: (9000,)
# File: A01174 - Shape: (9000,)
# File: A03372 - Shape: (18000,)
# File: A03927 - Shape: (18000,)
# File: A04695 - Shape: (9000,)
# File: A03943 - Shape: (9000,)
# File: A07709 - Shape: (9000,)
# File: A07129 - Shape: (9000,)
# File: A00185 - Shape: (9000,)
# File: A00920 - Shape: (9000,)
# File: A06553 - Shape: (9000,)
# File: A03007 - Shape: (18000,)
# File: A03376 - Shape: (9000,)
# File: A07491 - Shape: (9000,)
# File: A01101 - Shape: (9000,)
# File: A07635 - Shape: (9000,)
# File: A01862 - Shape: (9000,)
# File: A04842 - Shape: (9000,)
# File: A04781 - Shape: (9000,)
# File: A07420 - Shape: (9000,)
# File: A05510 - Shape: (9000,)

# %% [markdown]
# As you can see, the signals have different lengths. However, for this network implementation, we need the input shape to be fixed.
#
# Most of the signals have **9000** samples (30 seconds, considering the **300 Hz** sampling frequency), so let's use this value as our fixed input shape.
#
# If the signal is too short (< 9000 samples), we **pad the vector with zeros** to match the required size. Use the function ``pad`` of the numpy library (loaded as `np`), you can find [here](https://numpy.org/doc/stable/reference/generated/numpy.pad.html) the documentation. Pad half on the left (``` int(np.ceil(tot_pads / 2))```) and half on the right (```int(np.floor(tot_pads / 2))```), ceil and floor are used to manage odd values for ``` tot_pad```. Use ```mode='constant'``` to pad with zeros (default value for the function).
#
# If the signal is too long (> 9000 samples), we randomly select a portion of the signal (**crop**) to match the required size. This operation should be repeated every time the data is sampled during the training phase, always selecting a different portion of the signal. In this way, we exploit all the available information (**never waste your data**).
#
#  **NOTE**: Typically, validation/test should be performed always on the same data (without any randomness). For this reason, we also include the parameter **center_crop**. if *center_crop=True*, instead of randomly selecting 9000 samples from the signal, we always take them in the middle of the signal. *center_crop* will be set to *True* for the validation dataset.
#
#  The following plots show the signal 'A03027', which has 18000 samples, and an example of 3 random crops.
#
#  **Hint**: Try to set *center_crop=True* in the code to be sure the 3 crops are exactly the same.

# %%
# NOTE: inside a function there can be different "return" statements for different conditions
# when a condition is met and the return statement is executed, all the code below will not be executed

def random_crop(data, target_size=9000, center_crop=False):
    N = data.shape[0]
    
    # Return data if correct size
    if N == target_size:
        return data
    
    # If data is too small, then pad with zeros
    if N < target_size:
        #pad 
        data = np.pad(data, (0, target_size - N), 'constant')
        return data
    
    # if the signal is too long (> 9000 samples), we randomly select a portion of the signal 
    # to match the required size. This operation should be repeated every time the data 
    # is sampled during the training phase, always selecting a different portion of the signal.
    # Random Crop (always centered if center_crop=True)

    if center_crop:
        # set the starting point to perform a crop in the middle
        from_ = np.floor((N - target_size) / 2)
    else:
        # select a random variable to start the crop 
        # NOTE: the maximum position where you can start is np.floor(N - target_size) 
        # otherwise you will not be able to take target_size samples
        from_ = np.random.randint(0, np.floor(N - target_size))

    to_ = from_ + target_size
    return data[int(from_):int(to_)]

# Example
file_name = 'A03027'
data = load_data(file_name, data_dir)
plt.figure()
plt.plot(data)
plt.title('Entire signal')

for i in range(3):
    plt.figure()
    plt.plot (random_crop(data, center_crop=True))
    plt.title('Crop {}'.format(i+1))

# %% [markdown]
# ## 2 - Data Loading using the Dataset API
#
# At this point, you can easily apply the previously defined methods to the entire dataset and the results will probably still fit in your (RAM) memory.
#
# But what if this is not the case?
#
# Let's suppose that the dataset does not entirely fit in your memory, and maybe your preprocessing pipeline is computationally intensive.
#
# Under these circumstances, you have to read data from files (maybe stored in a remote server) every time you need a new sample, which can easily be the main bottleneck of the entire training process. A proper and optimized data-loading pipeline is of primary importance in many cases. As you have seen in the second part of Lab 2 and in Lab 3, you can exploit the Tensorflow Dataset API, which exposes many useful functions to assist you in this process (documentation [here](https://www.tensorflow.org/guide/datasets)).
#
# The main goal of this phase is to create a `tf.data.Dataset` object to efficiently load and preprocess your data.
#
# First, let's put together the loading and preprocessing methods in a single function `load_and_preprocess_data`.
#
# **NOTE**: As you have seen in Labs 3 and 4, TensorFlow takes as input 32-bit floating point data. Make sure to return the proper data type to be fed to the network. The use of 64-bit floats would make the network training extremely inefficient on most GPUs. Furthermore, a 64-bit precision is not typically required for network training.

# %%
def load_and_preprocess_data(file_name, data_dir):
    # Load data
    data = load_data(file_name, data_dir)
    # Baseline wander removal
    data = baseline_wander_removal(data)
    # Normalize
    data = normalize_data(data)
    return data.astype(np.float32)

# Example
file_name = 'A00001'
data = load_and_preprocess_data(file_name, data_dir)

plt.figure()
plt.plot(data)

# %% [markdown]
# ### 2.1 - Dataset definition
# Now, let's define the `create_dataset` function following the same steps in Lab 3.
#
# #### - **Create a Dataset object**
# We use the method `from_tensor_slices` to instantiate a `tf.data.Dataset` object, which iteratively gets data from given tensors (documentation [here](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#from_tensor_slices)).
# While in Lab 3 we implemented an unsupervised learning technique (autoencoder) in this lab we want to implement a classifier (supervised learning) and, in turn, we need to include labels in our Dataset.
# Specifically, we use as arguments a tuple composed of the `file_names` list (\['A00001','A00002'...\]) and the `labels` list (\[0,0,1,0,...\]), both extracted from the `reference_df` dataframe (e.g., the previously evaluated *train_reference_df* or *val_reference_df*)
#
# #### - **Map the load_and_preprocess_data function**
# In this case, we want to transform the filename string (e.g., b'A00001') to a 32-bit tensor containing the actual preprocessed data using the `load_and_preprocess_data` function.
# We use the `map()` method (documentation [here](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#map)) combined with `tf.numpy_function` (documentation [here](https://www.tensorflow.org/api_docs/python/tf/numpy_function)) to include arbitrary python functions inside the TensorFlow graph.
#
# The `map()` function converts your dataset entries from (filename, label) to (preprocessed ECG data, label).
#
# #### - **Cache the dataset**
# In this example, both the baseline wander removal and the normalization steps can be performed a single time on the entire dataset, since the result is always the same. Thus, we use caching to store partial results both in a file or in memory (RAM), documentation [here](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#cache).
#
# **IMPORTANT NOTE**: Remember that the order of the dataset transformations is very important, especially when using a caching system. For example, if you applied the cache **after** the random crop operation, your samples would be cropped only the first time, and stored in the cache. All the subsequent calls would have always returned the same exact crop, resulting in both a waste of data and more overfitting issues.
#
# #### - **Shuffle**
# Documentation [here](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle).
#
# #### - **Repeat the dataset indefinitely**
# Documentation [here](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#repeat).
#
# #### - **Map the crop function**
# Now we can map the random crop function. The previous important note for the cache also holds for the ``repeat()`` function. If you applied the random crop **before** the ``repeat()``, the same crop would have been repeated indefinitely. So always pay attention to the proper order!
#
# #### - **Correct input shape for the network**
# Since the required network input shape is (batch, time_axis, channels) in this case, we need to add the channel axis to the data. We simply expand the rank of the tensor from the shape (9000,) to (9000, 1). The data content is not affected.
#
# #### - **Batch**
# Put together *batch_size* samples into a single batch of data, which will be the input of the network. The shape of the data changes from (9000, 1) to (batch_size, 9000, 1).
#
# #### - **Prefetch**
# With this operation we go from this situation:
#
# <img src="img/datasets_without_pipelining.png" width="600"/>
#
# to:
#
# <img src="img/datasets_with_pipelining.png" width="600"/>
#
# You can find more details [here](https://www.tensorflow.org/guide/performance/datasets), along with additional tips and tricks for performance optimization.

# %%
def create_dataset(reference_df, input_size, center_crop, batch_size, shuffle=True, cache_file=False, target_size=9000):
    # Convert dataframe to lists
    file_names = list(reference_df.index)
    labels = reference_df['label']

    # Create a Dataset object
    dataset = tf.data.Dataset.from_tensor_slices((file_names, labels))

    # Map the load_and_preprocess_data function
    py_func = lambda file_name, label: (tf.numpy_function(load_and_preprocess_data, [file_name, data_dir], tf.float32), label)
    dataset = dataset.map(py_func)
    # Cache dataset
    if cache_file:
        dataset = dataset.cache(cache_file)

    # Shuffle
    if shuffle:
        dataset = dataset.shuffle(len(reference_df))

    # Repeat the dataset indefinitely
    dataset = dataset.repeat(None)

    # Map the crop function
    py_func = lambda data, label: (tf.ensure_shape(tf.numpy_function(random_crop, [data, target_size, center_crop], tf.float32),
                                                   input_size), label)
    dataset = dataset.map(py_func)

    # Correct input shape for the network
    dataset = dataset.map(lambda data, label: (tf.expand_dims(data, 1), label))

    # Batch
    dataset = dataset.batch(batch_size)

    # Prefetch
    dataset = dataset.prefetch(1)

    print (dataset)
    return dataset

# %% [markdown]
# ### 2.2 - Dataset initialization
# Now we can finally define our training and validation dataset.
#
# We also evaluate the number of steps (*train_steps* and *val_steps*) required to load and process the entire dataset (num. of samples / batch_size).
#
# Remember that *center_crop* should be *False* for the training set and *True* for the validation, and shuffling should be enabled only for the training set.

# %%
input_size = 9000
batch_size = 32
try:
    train_reference_df.set_index('file', inplace=True)
    val_reference_df.set_index('file', inplace=True)
except:
    pass

train_dataset = create_dataset(train_reference_df, 
                               input_size=input_size, 
                               center_crop=False, 
                               batch_size=batch_size, 
                               shuffle=True,
                               cache_file='train_cache')

val_dataset = create_dataset(val_reference_df, 
                             input_size=input_size, 
                             center_crop=True, 
                             batch_size=batch_size, 
                             shuffle=False,
                             cache_file='val_cache')

train_steps = int(np.ceil(len(train_reference_df)/batch_size))
val_steps = int(np.ceil(len(val_reference_df)/batch_size))

print('Train steps: {}'.format(train_steps))
print('Val steps: {}'.format(val_steps))
# Out:
# <PrefetchDataset shapes: ((None, 9000, 1), (None,)), types: (tf.float32, tf.int64)>
# <PrefetchDataset shapes: ((None, 9000, 1), (None,)), types: (tf.float32, tf.int64)>
# Train steps: 146
# Val steps: 37

# %% [markdown]
# For example, to show the effectiveness of the caching system, let's try to create a small dataset (just 96 samples). Then, let's measure the loading time of 3 epochs.
#
# As you can see, the first epoch requires much longer to load and process data. While the other 2 prepare data almost instantly.

# %% [markdown]
#  To save some time (the full creation of the caches may require about 30 minutes depending on your hardware), the caches of the train and validation sets are provided. Keep in mind that this is not a good practice and may cause some issues. Typically cache files should not be transferred among different machines.
#
#  If you have problems with the provided cache files, just delete/rename them (all the files starting with *train_cache* and *val_cache*) and recreate your own caches.

# %% [markdown]
#  ## 3 - Model definition
#  Here, you are free to define your network architecture.
#
#  As a starting point, we propose the following network, where the first three layers are monodimensional convolutions (the input is a signal), and then we have a gated recurrent unit (GRU) before the fully connected layer:
#  - Input of shape (None, 9000, 1)
#  - Layer 1
#    - Conv1D with 32 channels, kernel size 9, and stride 4
#    - Batchnorm
#    - ReLu
#  - Layer 2
#    - Conv1D with 64 channels, kernel size 9, and stride 4
#    - Batchnorm
#    - ReLu
#  - Layer 3
#    - Conv1D with 128 channels, kernel size 9, and stride 4
#    - Batchnorm
#    - ReLu
#  - Layer 4
#    - GRU with 128 units
#  - Layer 5
#    - Dense with 1 output (probability of the input sample to be an Afib)
#
# Layers' documentation [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers#classes_2).
# Below, you find the structure to build the network model using the `Model` class but feel free to use the `Sequential` one instead.
#
# **NOTE**: Even though theoretically a recurrent network is capable of storing indefinite long-term relationships, practical backpropagation limits and numerical issues restrict their actual memory. Feeding a GRU directly with 9000 samples (i.e., without using the conv layers) is quite inefficient and unlikely the network will converge to a good minimum. The purposes of the convolutional layers are: **1)** to reduce the dimensionality of the input (using the strides) and **2)** to extract higher-level information before the GRU layer.
#
# **Hint**: Since we do not have real-time requirements, you can also consider using a bidirectional GRU.

# %%
def MyModel(input_shape):
    """
    Arguments:
    input_shape -- shape of the data of the dataset

    Returns:
    model -- a tf.keras.Model() instance
    """
    
    X_input = tf.keras.Input(input_shape)

    # CONV -> Batch Normalization -> ReLU Block applied to X
    
    X = tf.keras.layers.Conv1D(filters=32, kernel_size=9, strides=4)(X_input) # CONV1D
    X = tf.keras.layers.BatchNormalization()(X) # Batch normalization
    X = tf.keras.layers.Activation('relu')(X) # ReLu activation

    # CONV -> Batch Normalization -> ReLU Block applied to X
    X = tf.keras.layers.Conv1D(filters=64, kernel_size=9, strides=4)(X) # CONV1D
    X = tf.keras.layers.BatchNormalization()(X) # Batch normalization
    X = tf.keras.layers.Activation('relu')(X) # ReLu activation

    # CONV -> Batch Normalization -> ReLU Block applied to X
    X = tf.keras.layers.Conv1D(filters=128, kernel_size=9, strides=4)(X) # CONV1D
    X = tf.keras.layers.BatchNormalization()(X) # Batch normalization
    X = tf.keras.layers.Activation('relu')(X) # ReLu activation
    
    # GRU 
    X = tf.keras.layers.GRU(units=128)(X) # GRU

    # FLATTEN X + FULLYCONNECTED
    X = tf.keras.layers.Flatten()(X) # Flatten
    X = tf.keras.layers.Dense(1, activation='relu')(X) # Dense

    # Create the keras model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = tf.keras.Model(inputs = X_input, outputs = X, name='GRU_CONV')
    
    return model

# %%
input_shape = (input_size, 1)

# Call the function to create the model and 
# compile it (Hint. Parameters: optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model = MyModel(input_shape)
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %% [markdown]
#  ## 4 - Model training and testing
#  ### 4.1 - Model training
#  Now let's train the model for some epochs. Then plot the loss values and the accuracy during training.
#  To fit the model use the parameters:
#  ```python
# model.fit(train_dataset, epochs=num_epochs, steps_per_epoch=train_steps, validation_data=val_dataset, validation_steps=val_steps, callbacks=[early_stop_callback)
# ```
# Here we use the early stopping [callback](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping).

# %%
# Train the model
num_epochs = 20

early_stop_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                                       patience=5)

# Fit the model
history = model.fit(train_dataset,
                    epochs=num_epochs,
                    steps_per_epoch=train_steps,
                    validation_data=val_dataset,
                    validation_steps=val_steps,
                    callbacks=[early_stop_callback])


# Save the model
model.save('new_model.h5')
# Out:
# Epoch 1/20
# 146/146 [==============================] - 30s 202ms/step - loss: 2.0041 - accuracy: 0.8701 - val_loss: 2.0063 - val_accuracy: 0.8699
# Epoch 2/20
# 146/146 [==============================] - 33s 228ms/step - loss: 2.0041 - accuracy: 0.8701 - val_loss: 2.0063 - val_accuracy: 0.8699
# Epoch 3/20
# 146/146 [==============================] - 40s 273ms/step - loss: 2.0041 - accuracy: 0.8701 - val_loss: 2.0063 - val_accuracy: 0.8699
# Epoch 4/20
# 146/146 [==============================] - 33s 225ms/step - loss: 1.9942 - accuracy: 0.8707 - val_loss: 2.0063 - val_accuracy: 0.8699
# Epoch 5/20
# 146/146 [==============================] - 31s 212ms/step - loss: 2.0041 - accuracy: 0.8701 - val_loss: 2.0063 - val_accuracy: 0.8699
# Epoch 6/20
# 146/146 [==============================] - 24s 166ms/step - loss: 2.0008 - accuracy: 0.8703 - val_loss: 2.0063 - val_accuracy: 0.8699

# %%
# Plot loss
plt.figure()
plt.plot(history.history['loss'], label='Train loss')
plt.plot(history.history['val_loss'], label='Val loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

# Plot accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train accuracy')
plt.plot(history.history['val_accuracy'], label='Val accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# If you do not want to wait for the training to finish, you can load some pretrained models.
#
# Just uncomment the line of code below.

# %%
# model = tf.keras.models.load_model('model.h5')

model.summary()
# Out:
# Model: "GRU_CONV"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 9000, 1)]         0
#
#  conv1d_3 (Conv1D)           (None, 2248, 32)          320
#
#  batch_normalization_3 (Batc  (None, 2248, 32)         128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2248, 32)          0
#
#  conv1d_4 (Conv1D)           (None, 560, 64)           18496
#
#  batch_normalization_4 (Batc  (None, 560, 64)          256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 560, 64)           0
#
#  conv1d_5 (Conv1D)           (None, 138, 128)          73856
#
#  batch_normalization_5 (Batc  (None, 138, 128)         512
#  hNormalization)
#
#  activation_5 (Activation)   (None, 138, 128)          0
#
#  gru_1 (GRU)                 (None, 128)               99072
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 192,769
# Trainable params: 192,321
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ## 5 - Some validation metrics
# The accuracy is not a good metric when the dataset is unbalanced, as in this case. Additional metrics are required to have a good understanding of the classifier performance, as seen in Lab 4.
#
# Let's evaluate the **precision**, **recall** and **fscore** metrics using some methods from the *scikit-learn* library (documentation [here](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics)).
#
# Recap from Lab 4: first, we need the output of the network for all the validation samples. To obtain it use:
# ```python
# model.predict(val_dataset, steps=val_steps)[:len(val_labels)].squeeze()
# ```
# The ```[:len(val_labels)]``` is needed because the elements in ```[len(val_labels):]``` are not part of our dataset, they are added to complete the batch (in fact ```len(val_labels)=1167``` while to complete the final batch the elements are a total of 1184.
#
# Then, if the output is < 0.5, the estimated class is normal sinus rhythm, otherwise an Afib has been detected: use
# ```python
# (val_preds > 0.5).astype(int)
# ```

# %%
# Get the validation labels
val_labels = val_reference_df['label'].values

# Get the network output for the validation set
val_est_classes = model.predict(val_dataset, steps=val_steps).flatten().astype(np.int)

# Evaluate accuracy
accuracy = np.mean(val_est_classes == val_labels)

# Evaluate precision, recall and fscore
precision, recall, fscore, _= precision_recall_fscore_support(val_labels, val_est_classes, average='binary')

print('#### VALIDATION PERFORMANCE')
print('Accuracy: {:.2f}%'.format(accuracy*100))
print('Precision (fraction of ECG classified as Afib that are actually Afib): {:.2f}%'.format(precision*100))
print('Recall (fraction of Afib correctly classified as Afib): {:.2f}%'.format(recall*100))
print('Fscore (harmonic mean of precision and recall): {:.2f}%'.format(fscore*100))
# Out:
# <ipython-input-134-238eed706173>:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   val_est_classes = model.predict(val_dataset, steps=val_steps).flatten().astype(np.int)
# <ipython-input-134-238eed706173>:9: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   accuracy = np.mean(val_est_classes == val_labels)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-238eed706173> in <module>
#      10
#      11 # Evaluate precision, recall and fscore
# ---> 12 precision, recall, fscore, _= precision_recall_fscore_support(val_labels, val_est_classes, average='binary')
#      13
#      14 print('#### VALIDATION PERFORMANCE')
#
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1554     if beta < 0:
#    1555         raise ValueError("beta should be >=0 in the F-beta score")
# -> 1556     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1557
#    1558     # Calculate tp_sum, pred_sum, true_sum ###
#
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1355         raise ValueError("average has to be one of " + str(average_options))
#    1356
# -> 1357     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1358     # Convert to Python primitive type to avoid NumPy type / Python str
#    1359     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true, input_name="y_true")
#      86     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     385     uniques = np.unique(lengths)
#     386     if len(uniques) > 1:
# --> 387         raise ValueError(
#     388             "Found input variables with inconsistent numbers of samples: %r"
#     389             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [1167, 1184]

# %% [markdown]
#  As you can see, even though the accuracy is around 97% (using the pre-trained model), the precision and recall are considerably smaller (not too bad anyway).
#
# **NOTE** You should be careful when dealing with an unbalanced dataset. For example, since in this case, about 87% of the samples are of class 0, a dummy classifier whose output is always 0 would get an 87% accuracy, which may appear as a good result at first, while it's actually the worst you can get.
# In the same case, precision and recall would easily point out the bad performances.

# %% [markdown]
# ### 5.1 - Receiver operating characteristic (ROC) curve
# Plot the ROC as seen in Lab 4. The curve is obtained by evaluating the *False Positive Rate* and the *True Positive Rate* by varying the threshold used to infer the estimated classes (0.5 in the previous case).

# %%
fpr, tpr, _ = roc_curve(val_labels, val_preds)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC)')
plt.legend(loc="lower right")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-39b18f873877> in <module>
# ----> 1 fpr, tpr, _ = roc_curve(val_labels, val_preds)
#       2 roc_auc = auc(fpr, tpr)
#       3
#       4 plt.figure()
#       5 plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
#
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     977
#     978     """
# --> 979     fps, tps, thresholds = _binary_clf_curve(
#     980         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     981     )
#
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     738         raise ValueError("{0} format is not supported".format(y_type))
#     739
# --> 740     check_consistent_length(y_true, y_score, sample_weight)
#     741     y_true = column_or_1d(y_true)
#     742     y_score = column_or_1d(y_score)
#
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     385     uniques = np.unique(lengths)
#     386     if len(uniques) > 1:
# --> 387         raise ValueError(
#     388             "Found input variables with inconsistent numbers of samples: %r"
#     389             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [1167, 1184]

# %% [markdown]
# ### 5.2 - Precision-Recall Curve (PRC)
# Plot the PRC.

# %%
prec, rec, _ = precision_recall_curve(val_labels, val_preds)

plt.figure()
plt.plot(prec, rec, color='darkorange', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Precision')
plt.ylabel('Recall')
plt.title('Precision-Recall Curve (PRC)')

# %% [markdown]
# Congratulations! Lab 5 successfully completed :)
